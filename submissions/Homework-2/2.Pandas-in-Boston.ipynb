# %% [markdown]
# (In order to load the stylesheet of this notebook, execute the last code cell in this notebook)

# %% [markdown]
# # Analyze the data from the Mayor's 24-hour hotline in Boston using Pandas

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this assignment, we will practice some basic skills on working with data. We will see how to read, access, clean, filter and plot a dataset.
#
# ---------------------------

# %% [markdown]
# ## Step 1. Downaloading the data

# %% [markdown]
# The data that we will be using are freely available online, by the [City of Boston](https://data.cityofboston.gov/). A brief description of the 311 service can be found [here](http://www.cityofboston.gov/mayor/24/). You can download the whole dataset, which extends from 2011 until now (updated every day) from [here](https://data.cityofboston.gov/City-Services/Mayor-s-24-Hour-Hotline-Service-Requests/awu8-dc52?). However, it contains over 555,000 records and, as a result, it's more than 245 MB in size. In the homework repository, you can find a small part of it that covers the months of January-February 2015, under the filename `cases_2015.csv`.

# %% [markdown]
# During these two months, Boston experienced one of the highest levels of snowfalls. We will take this opportunity and see how this situation affected the 311 center. We will also be using data from [NOAA National Climatic Data Center](http://www.ncdc.noaa.gov/cdo-web/) regarding the levels of snowfall for the dates that we are interested in. This dataset is also available in our repository for your convenience under the file `snow.csv`. You can read its documentation [here](http://www.ncdc.noaa.gov/cdo-web/datasets).

# %% [markdown]
# -----------------

# %% [markdown]
# ## Step 2. Reading the data

# %% [markdown]
# The first thing we want to do is load the data as Pandas *DataFrames*.

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
from datetime import datetime
from matplotlib import pyplot as plt

# %%
boston = pd.read_csv('cases_2015.csv')

# %% [markdown]
# We need to take a brief look at the data, so that we get an intuition about what we are dealing with. Your first task is to do just that: print some part of the dataset **(5 pts)**

# %%
# Print part of the dataset here
# Print the first 10 results
print boston.head(10)
# Print more
# print boston
# Out:
#    CASE_ENQUIRY_ID              OPEN_DT            TARGET_DT  \
# 0     101001240734  2015-01-01 00:20:09                  NaN
# 1     101001240735  2015-01-01 00:25:23  2015-01-16 08:30:00
# 2     101001240736  2015-01-01 00:25:36  2015-01-16 08:30:00
# 3     101001240740  2015-01-01 01:45:37                  NaN
# 4     101001240742  2015-01-01 02:24:59                  NaN
# 5     101001240743  2015-01-01 03:08:01                  NaN
# 6     101001240744  2015-01-01 03:35:10  2015-01-06 08:30:00
# 7     101001240746  2015-01-01 03:46:15                  NaN
# 8     101001240747  2015-01-01 04:01:30  2015-01-06 08:30:00
# 9     101001240750  2015-01-01 04:12:40                  NaN
#
#              CLOSED_DT OnTime_Status CASE_STATUS  \
# 0  2015-01-02 09:08:42        ONTIME      Closed
# 1  2015-01-02 16:17:43        ONTIME      Closed
# 2                  NaN       OVERDUE        Open
# 3                  NaN        ONTIME        Open
# 4  2015-01-02 09:09:00        ONTIME      Closed
# 5  2015-01-02 09:09:15        ONTIME      Closed
# 6  2015-01-01 05:45:27        ONTIME      Closed
# 7                  NaN        ONTIME        Open
# 8  2015-01-01 05:06:50        ONTIME      Closed
# 9                  NaN        ONTIME        Open
#
#                                       CLOSURE_REASON  \
# 0                             Case Closed Case Noted
# 1  Case Closed Duplicate of Existing Case duplica...
# 2                                                NaN
# 3                                                NaN
# 4                             Case Closed Case Noted
# 5                             Case Closed Case Noted
# 6             Case Closed Case Resolved clean up mva
# 7                                                NaN
# 8     Case Closed Case Resolved clean up the  debris
# 9                                                NaN
#
#                      CASE_TITLE                  SUBJECT           REASON  \
# 0                         Other  Mayor's 24 Hour Hotline     Notification
# 1                       PRINTED  Public Works Department    Street Lights
# 2                       PRINTED  Public Works Department    Street Lights
# 3                  Animal Found           Animal Control    Animal Issues
# 4                          Fire  Mayor's 24 Hour Hotline     Notification
# 5                          Fire  Mayor's 24 Hour Hotline     Notification
# 6  Requests for Street Cleaning  Public Works Department  Street Cleaning
# 7                   Animal Lost           Animal Control    Animal Issues
# 8  Requests for Street Cleaning  Public Works Department  Street Cleaning
# 9                  Animal Found           Animal Control    Animal Issues
#
#           ...          precinct land_usage    LOCATION_STREET_NAME  \
# 0         ...               503          E            33 Beacon St
# 1         ...               502          C      145-151 Ipswich St
# 2         ...               502          C      145-151 Ipswich St
# 3         ...              2010         R4      4833 Washington St
# 4         ...               708         R2          10 Washburn St
# 5         ...               709         R3  841-843 Dorchester Ave
# 6         ...              1705         RC          320 Talbot Ave
# 7         ...              1611         R1            246 Minot St
# 8         ...              1813          E           1137 River St
# 9         ...              1609         CD            730 Adams St
#
#   LOCATION_ZIPCODE Property_Type Property_ID  LATITUDE LONGITUDE  \
# 0             2108       Address       11072   42.3574  -71.0648
# 1             2215       Address      157262   42.3474  -71.0944
# 2             2215       Address      157262   42.3474  -71.0944
# 3             2132       Address      331760   42.2711  -71.1464
# 4             2125       Address      143386   42.3254  -71.0574
# 5             2125       Address       48752   42.3220  -71.0570
# 6             2124       Address      317720   42.2906  -71.0727
# 7             2124       Address       96119   42.2834  -71.0576
# 8             2136       Address      116326   42.2572  -71.1204
# 9             2122       Address         949   42.2847  -71.0550
#
#                  Source    Geocoded_Location
# 0      Constituent Call  (42.3574, -71.0648)
# 1  Citizens Connect App  (42.3474, -71.0944)
# 2  Citizens Connect App  (42.3474, -71.0944)
# 3      Constituent Call  (42.2711, -71.1464)
# 4      Constituent Call  (42.3254, -71.0574)
# 5      Constituent Call    (42.322, -71.057)
# 6      Constituent Call  (42.2906, -71.0727)
# 7      Constituent Call  (42.2834, -71.0576)
# 8      Constituent Call  (42.2572, -71.1204)
# 9      Constituent Call   (42.2847, -71.055)
#
# [10 rows x 33 columns]

# %% [markdown]
# Another useful thing is to get a short summary of the columns and their data types. Make a call to the required function for this **(5 pts)**

# %%
# Print information about the columns of the dataset
print boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46698 entries, 0 to 46697
# Data columns (total 33 columns):
# CASE_ENQUIRY_ID                   46698 non-null int64
# OPEN_DT                           46698 non-null object
# TARGET_DT                         41129 non-null object
# CLOSED_DT                         35141 non-null object
# OnTime_Status                     46694 non-null object
# CASE_STATUS                       46698 non-null object
# CLOSURE_REASON                    35175 non-null object
# CASE_TITLE                        46679 non-null object
# SUBJECT                           46698 non-null object
# REASON                            46698 non-null object
# TYPE                              46698 non-null object
# QUEUE                             46698 non-null object
# Department                        46698 non-null object
# SubmittedPhoto                    7245 non-null object
# ClosedPhoto                       1217 non-null object
# Location                          44442 non-null object
# fire_district                     44229 non-null float64
# pwd_district                      44338 non-null object
# city_council_district             44431 non-null float64
# police_district                   44358 non-null object
# neighborhood                      44402 non-null object
# neighborhood_services_district    44431 non-null float64
# ward                              44438 non-null object
# precinct                          44297 non-null float64
# land_usage                        33332 non-null object
# LOCATION_STREET_NAME              44442 non-null object
# LOCATION_ZIPCODE                  35291 non-null float64
# Property_Type                     44442 non-null object
# Property_ID                       44442 non-null float64
# LATITUDE                          46698 non-null float64
# LONGITUDE                         46698 non-null float64
# Source                            46698 non-null object
# Geocoded_Location                 46698 non-null object
# dtypes: float64(8), int64(1), object(24)
# memory usage: 12.1+ MB
# None

# %% [markdown]
# As you can see, the `OPEN_DT`, `TARGET_DT`, and `CLOSED_DT` columns, all of which should be dates, have been misclassified as `object` instead of datetime. Re-write the code that reads from a csv, in order to parse the above columns as datetimes. **(5 pts)**

# %%
# Read the date columns as datetime objects
boston = pd.read_csv('cases_2015.csv', parse_dates=['OPEN_DT','CLOSED_DT','TARGET_DT'])

# %% [markdown]
# Make sure that the column data types are exactly as expected:

# %%
# Print the data types of the columns again
print boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46698 entries, 0 to 46697
# Data columns (total 33 columns):
# CASE_ENQUIRY_ID                   46698 non-null int64
# OPEN_DT                           46698 non-null datetime64[ns]
# TARGET_DT                         41129 non-null datetime64[ns]
# CLOSED_DT                         35141 non-null datetime64[ns]
# OnTime_Status                     46694 non-null object
# CASE_STATUS                       46698 non-null object
# CLOSURE_REASON                    35175 non-null object
# CASE_TITLE                        46679 non-null object
# SUBJECT                           46698 non-null object
# REASON                            46698 non-null object
# TYPE                              46698 non-null object
# QUEUE                             46698 non-null object
# Department                        46698 non-null object
# SubmittedPhoto                    7245 non-null object
# ClosedPhoto                       1217 non-null object
# Location                          44442 non-null object
# fire_district                     44229 non-null float64
# pwd_district                      44338 non-null object
# city_council_district             44431 non-null float64
# police_district                   44358 non-null object
# neighborhood                      44402 non-null object
# neighborhood_services_district    44431 non-null float64
# ward                              44438 non-null object
# precinct                          44297 non-null float64
# land_usage                        33332 non-null object
# LOCATION_STREET_NAME              44442 non-null object
# LOCATION_ZIPCODE                  35291 non-null float64
# Property_Type                     44442 non-null object
# Property_ID                       44442 non-null float64
# LATITUDE                          46698 non-null float64
# LONGITUDE                         46698 non-null float64
# Source                            46698 non-null object
# Geocoded_Location                 46698 non-null object
# dtypes: datetime64[ns](3), float64(8), int64(1), object(21)
# memory usage: 12.1+ MB
# None

# %% [markdown]
# ## Step 3. Filtering and plotting the data

# %% [markdown]
# Now that we read the data and took a quick look, we can start playing around with it. As you have already noticed, there is very little documentation on the dataset itself. In such occasions, we need to look at the dataset very extensively, to get a good feel of its structure. This part, together with what we will do next, is a significant part of the *data cleaning* process.

# %% [markdown]
# To practice our filtering skills, let's try to isolate the cases that were opened in February **(5 pts)**

# %%
# Write code that filters the dataframe and keeps only the cases that were opened in February
import datetime
start_date = datetime.date(2015,2,1)
end_date = datetime.date(2015,3,1)
february = boston[(boston.OPEN_DT > start_date)]
february = february[(february.OPEN_DT < end_date)]
print february
# Out:
#        CASE_ENQUIRY_ID             OPEN_DT           TARGET_DT  \
# 20777     101001266300 2015-02-01 00:11:47 2015-02-09 08:30:00
# 20778     101001266301 2015-02-01 00:12:23                 NaT
# 20779     101001266302 2015-02-01 00:14:44 2015-02-04 08:30:00
# 20780     101001266303 2015-02-01 00:19:43 2015-02-04 08:30:00
# 20781     101001266304 2015-02-01 00:20:03 2015-02-04 08:30:00
# 20782     101001266305 2015-02-01 00:20:42                 NaT
# 20783     101001266306 2015-02-01 00:21:41 2015-02-04 08:30:00
# 20784     101001266307 2015-02-01 00:36:38 2015-02-09 08:30:00
# 20785     101001266309 2015-02-01 00:44:21 2015-02-04 08:30:00
# 20786     101001266310 2015-02-01 00:45:12 2015-02-17 08:30:00
# 20787     101001266311 2015-02-01 00:47:35 2015-02-04 08:30:00
# 20788     101001266312 2015-02-01 00:50:28 2015-03-03 00:50:28
# 20789     101001266313 2015-02-01 01:05:29 2015-02-04 08:30:00
# 20790     101001266314 2015-02-01 01:05:54 2015-02-04 08:30:00
# 20791     101001266315 2015-02-01 01:05:58 2015-02-03 08:30:00
# 20792     101001266316 2015-02-01 01:10:50 2015-02-04 08:30:00
# 20793     101001266317 2015-02-01 01:35:14 2015-02-09 08:30:00
# 20794     101001266318 2015-02-01 01:38:14 2015-02-09 08:30:00
# 20795     101001266319 2015-02-01 01:40:24 2015-02-09 08:30:00
# 20796     101001266320 2015-02-01 01:43:09 2015-02-09 08:30:00
# 20797     101001266321 2015-02-01 02:05:38 2015-02-17 08:30:00
# 20798     101001266322 2015-02-01 03:43:54 2015-02-17 08:30:00
# 20799     101001266324 2015-02-01 05:00:44 2015-02-09 08:30:00
# 20800     101001266325 2015-02-01 05:35:17 2015-02-04 08:30:00
# 20801     101001266326 2015-02-01 05:39:39 2015-02-09 08:30:00
# 20802     101001266327 2015-02-01 05:43:59                 NaT
# 20803     101001266328 2015-02-01 05:44:40 2015-02-09 08:30:00
# 20804     101001266329 2015-02-01 06:03:21 2015-02-04 08:30:00
# 20805     101001266330 2015-02-01 06:17:18 2015-02-04 08:30:00
# 20806     101001266331 2015-02-01 09:38:36 2015-02-09 08:30:00
# ...                ...                 ...                 ...
# 46668     101001295365 2015-02-14 22:02:09 2015-02-19 08:30:00
# 46669     101001295366 2015-02-14 22:03:35                 NaT
# 46670     101001295367 2015-02-14 22:03:54 2015-02-24 08:30:00
# 46671     101001295368 2015-02-14 22:04:18 2015-02-19 08:30:00
# 46672     101001295370 2015-02-14 22:07:12 2015-02-19 08:30:00
# 46673     101001295371 2015-02-14 22:07:26 2015-02-19 08:30:00
# 46674     101001295372 2015-02-14 22:08:08 2015-03-16 22:08:07
# 46675     101001295374 2015-02-14 22:14:28 2015-02-24 08:30:00
# 46676     101001295375 2015-02-14 22:14:48 2015-02-24 08:30:00
# 46677     101001295376 2015-02-14 22:14:53 2015-02-19 08:30:00
# 46678     101001295379 2015-02-14 22:25:58 2015-02-19 08:30:00
# 46679     101001295380 2015-02-14 22:30:01 2015-02-19 08:30:00
# 46680     101001295381 2015-02-14 22:30:24 2015-03-03 08:30:00
# 46681     101001295382 2015-02-14 22:31:15 2015-03-03 08:30:00
# 46682     101001295384 2015-02-14 22:31:59 2015-03-03 08:30:00
# 46683     101001295385 2015-02-14 22:32:35 2015-03-03 08:30:00
# 46684     101001295386 2015-02-14 22:40:31 2015-03-03 08:30:00
# 46685     101001295388 2015-02-14 22:44:37 2015-03-03 08:30:00
# 46686     101001295389 2015-02-14 22:45:06 2015-03-03 08:30:00
# 46687     101001295391 2015-02-14 22:55:01 2015-02-19 08:30:00
# 46688     101001295392 2015-02-14 22:57:46 2015-02-19 08:30:00
# 46689     101001295393 2015-02-14 23:20:20                 NaT
# 46690     101001295394 2015-02-14 23:26:57 2015-02-24 08:30:00
# 46691     101001295395 2015-02-14 23:28:30 2015-02-19 08:30:00
# 46692     101001295396 2015-02-14 23:29:22 2015-02-24 08:30:00
# 46693     101001295400 2015-02-14 23:37:51 2015-02-19 08:30:00
# 46694     101001295401 2015-02-14 23:41:25                 NaT
# 46695     101001295402 2015-02-14 23:46:19 2015-02-24 08:30:00
# 46696     101001295406 2015-02-14 23:53:09 2015-03-03 08:30:00
# 46697     101001295407 2015-02-15 00:00:17                 NaT
#
#                 CLOSED_DT OnTime_Status CASE_STATUS  \
# 20777 2015-02-03 08:43:55        ONTIME      Closed
# 20778 2015-02-01 00:32:41        ONTIME      Closed
# 20779 2015-02-12 17:36:24       OVERDUE      Closed
# 20780 2015-02-12 17:36:24       OVERDUE      Closed
# 20781 2015-02-12 17:36:25       OVERDUE      Closed
# 20782                 NaT        ONTIME        Open
# 20783                 NaT       OVERDUE        Open
# 20784                 NaT       OVERDUE        Open
# 20785 2015-02-01 10:13:05        ONTIME      Closed
# 20786                 NaT        ONTIME        Open
# 20787 2015-02-02 10:38:12        ONTIME      Closed
# 20788 2015-02-03 09:06:03        ONTIME      Closed
# 20789                 NaT       OVERDUE        Open
# 20790 2015-02-02 05:41:29        ONTIME      Closed
# 20791 2015-02-01 13:40:26        ONTIME      Closed
# 20792 2015-02-12 17:36:25       OVERDUE      Closed
# 20793 2015-02-03 07:45:15        ONTIME      Closed
# 20794 2015-02-03 07:45:16        ONTIME      Closed
# 20795 2015-02-03 08:43:58        ONTIME      Closed
# 20796 2015-02-03 08:43:57        ONTIME      Closed
# 20797 2015-02-02 01:29:12        ONTIME      Closed
# 20798                 NaT        ONTIME        Open
# 20799 2015-02-02 13:35:19        ONTIME      Closed
# 20800 2015-02-02 08:37:29        ONTIME      Closed
# 20801 2015-02-04 08:33:15        ONTIME      Closed
# 20802                 NaT        ONTIME        Open
# 20803 2015-02-03 15:30:40        ONTIME      Closed
# 20804 2015-02-12 17:36:25       OVERDUE      Closed
# 20805 2015-02-02 05:41:29        ONTIME      Closed
# 20806 2015-02-03 08:37:06        ONTIME      Closed
# ...                   ...           ...         ...
# 46668                 NaT        ONTIME        Open
# 46669                 NaT        ONTIME        Open
# 46670                 NaT        ONTIME        Open
# 46671                 NaT        ONTIME        Open
# 46672                 NaT        ONTIME        Open
# 46673                 NaT        ONTIME        Open
# 46674                 NaT        ONTIME        Open
# 46675                 NaT        ONTIME        Open
# 46676                 NaT        ONTIME        Open
# 46677                 NaT        ONTIME        Open
# 46678                 NaT        ONTIME        Open
# 46679                 NaT        ONTIME        Open
# 46680                 NaT        ONTIME        Open
# 46681                 NaT        ONTIME        Open
# 46682                 NaT        ONTIME        Open
# 46683                 NaT        ONTIME        Open
# 46684                 NaT        ONTIME        Open
# 46685                 NaT        ONTIME        Open
# 46686                 NaT        ONTIME        Open
# 46687                 NaT        ONTIME        Open
# 46688                 NaT        ONTIME        Open
# 46689                 NaT        ONTIME        Open
# 46690                 NaT        ONTIME        Open
# 46691                 NaT        ONTIME        Open
# 46692                 NaT        ONTIME        Open
# 46693                 NaT        ONTIME        Open
# 46694                 NaT        ONTIME        Open
# 46695                 NaT        ONTIME        Open
# 46696                 NaT        ONTIME        Open
# 46697                 NaT        ONTIME        Open
#
#                                           CLOSURE_REASON  \
# 20777        Case Closed ADCLSD: Administratively Closed
# 20778                   Case Closed Case Resolved salted
# 20779      Case Closed Case Noted Snow has been removed.
# 20780      Case Closed Case Noted Snow has been removed.
# 20781      Case Closed Case Noted Snow has been removed.
# 20782                                                NaN
# 20783                                                NaN
# 20784                                                NaN
# 20785                             Case Closed Case Noted
# 20786                                                NaN
# 20787                      Case Closed Case Noted plowed
# 20788                                      Case Closed :
# 20789                                                NaN
# 20790                             Case Closed Case Noted
# 20791  Case Closed Case Resolved isolated short circu...
# 20792      Case Closed Case Noted Snow has been removed.
# 20793                  Case Closed TICKET: Ticket Issued
# 20794                  Case Closed TICKET: Ticket Issued
# 20795        Case Closed ADCLSD: Administratively Closed
# 20796        Case Closed ADCLSD: Administratively Closed
# 20797                             Case Closed Case Noted
# 20798                                                NaN
# 20799                        Case Closed CORR: Corrected
# 20800       Case Closed Case Noted Not in any violation.
# 20801                Case Closed NOACC: Closed-No Access
# 20802                                                NaN
# 20803                        Case Closed CORR: Corrected
# 20804      Case Closed Case Noted Snow has been removed.
# 20805                             Case Closed Case Noted
# 20806        Case Closed ADCLSD: Administratively Closed
# ...                                                  ...
# 46668                                                NaN
# 46669                                                NaN
# 46670                                                NaN
# 46671                                                NaN
# 46672                                                NaN
# 46673                                                NaN
# 46674                                                NaN
# 46675                                                NaN
# 46676                                                NaN
# 46677                                                NaN
# 46678                                                NaN
# 46679                                                NaN
# 46680                                                NaN
# 46681                                                NaN
# 46682                                                NaN
# 46683                                                NaN
# 46684                                                NaN
# 46685                                                NaN
# 46686                                                NaN
# 46687                                                NaN
# 46688                                                NaN
# 46689                                                NaN
# 46690                                                NaN
# 46691                                                NaN
# 46692                                                NaN
# 46693                                                NaN
# 46694                                                NaN
# 46695                                                NaN
# 46696                                                NaN
# 46697                                                NaN
#
#                                            CASE_TITLE  \
# 20777                                    Snow Removal
# 20778  Request for Snow Plowing (Emergency Responder)
# 20779                        Request for Snow Plowing
# 20780                        Request for Snow Plowing
# 20781                        Request for Snow Plowing
# 20782                                            Fire
# 20783                      Request for Pothole Repair
# 20784                                      Electrical
# 20785                        Request for Snow Plowing
# 20786                            Street Light Outages
# 20787                        Request for Snow Plowing
# 20788                  Heat - Excessive  Insufficient
# 20789                    Requests for Street Cleaning
# 20790                    Requests for Street Cleaning
# 20791                Major System Failure/////printed
# 20792                        Request for Snow Plowing
# 20793                                    Snow Removal
# 20794                                    Snow Removal
# 20795                                    Snow Removal
# 20796                                    Snow Removal
# 20797                          PublicWorks: Complaint
# 20798                               outage////printed
# 20799                                      Electrical
# 20800                             Parking Enforcement
# 20801                                      Electrical
# 20802                          Utility Casting Repair
# 20803                                        Plumbing
# 20804                        Request for Snow Plowing
# 20805                    Requests for Street Cleaning
# 20806                                    Snow Removal
# ...                                               ...
# 46668                      Request for Pothole Repair
# 46669  Request for Snow Plowing (Emergency Responder)
# 46670                                    Snow Removal
# 46671                        Request for Snow Plowing
# 46672                        Request for Snow Plowing
# 46673                        Request for Snow Plowing
# 46674                  Heat - Excessive  Insufficient
# 46675                                    Snow Removal
# 46676                                    Snow Removal
# 46677                        Request for Snow Plowing
# 46678                        Request for Snow Plowing
# 46679                        Request for Snow Plowing
# 46680                            Street Light Outages
# 46681                            Street Light Outages
# 46682                            Street Light Outages
# 46683                                     Sign Repair
# 46684                            Street Light Outages
# 46685                            Street Light Outages
# 46686                            Street Light Outages
# 46687                        Request for Snow Plowing
# 46688                       Missed Trash: District 1C
# 46689                            Misc. Snow Complaint
# 46690                                    Snow Removal
# 46691                        Request for Snow Plowing
# 46692                                    Snow Removal
# 46693                        Request for Snow Plowing
# 46694  Request for Snow Plowing (Emergency Responder)
# 46695                                    Snow Removal
# 46696                          PublicWorks: Complaint
# 46697                            Misc. Snow Complaint
#
#                                  SUBJECT                             REASON  \
# 20777              Inspectional Services                   Code Enforcement
# 20778            Public Works Department                    Street Cleaning
# 20779            Public Works Department                    Street Cleaning
# 20780            Public Works Department                    Street Cleaning
# 20781            Public Works Department                    Street Cleaning
# 20782            Mayor's 24 Hour Hotline                       Notification
# 20783            Public Works Department                Highway Maintenance
# 20784              Inspectional Services                           Building
# 20785            Public Works Department                    Street Cleaning
# 20786            Public Works Department                      Street Lights
# 20787            Public Works Department                    Street Cleaning
# 20788              Inspectional Services                            Housing
# 20789            Public Works Department                    Street Cleaning
# 20790            Public Works Department                    Street Cleaning
# 20791            Public Works Department                      Street Lights
# 20792            Public Works Department                    Street Cleaning
# 20793              Inspectional Services                   Code Enforcement
# 20794              Inspectional Services                   Code Enforcement
# 20795              Inspectional Services                   Code Enforcement
# 20796              Inspectional Services                   Code Enforcement
# 20797            Mayor's 24 Hour Hotline        Employee & General Comments
# 20798            Public Works Department                      Street Lights
# 20799              Inspectional Services                           Building
# 20800  Transportation - Traffic Division   Enforcement & Abandoned Vehicles
# 20801              Inspectional Services                           Building
# 20802            Public Works Department                Highway Maintenance
# 20803              Inspectional Services                           Building
# 20804            Public Works Department                    Street Cleaning
# 20805            Public Works Department                    Street Cleaning
# 20806              Inspectional Services                   Code Enforcement
# ...                                  ...                                ...
# 46668            Public Works Department                Highway Maintenance
# 46669            Public Works Department                    Street Cleaning
# 46670              Inspectional Services                   Code Enforcement
# 46671            Public Works Department                    Street Cleaning
# 46672            Public Works Department                    Street Cleaning
# 46673            Public Works Department                    Street Cleaning
# 46674              Inspectional Services                            Housing
# 46675              Inspectional Services                   Code Enforcement
# 46676              Inspectional Services                   Code Enforcement
# 46677            Public Works Department                    Street Cleaning
# 46678            Public Works Department                    Street Cleaning
# 46679            Public Works Department                    Street Cleaning
# 46680            Public Works Department                      Street Lights
# 46681            Public Works Department                      Street Lights
# 46682            Public Works Department                      Street Lights
# 46683  Transportation - Traffic Division                    Signs & Signals
# 46684            Public Works Department                      Street Lights
# 46685            Public Works Department                      Street Lights
# 46686            Public Works Department                      Street Lights
# 46687            Public Works Department                    Street Cleaning
# 46688            Public Works Department                         Sanitation
# 46689            Public Works Department  Administrative & General Requests
# 46690              Inspectional Services                   Code Enforcement
# 46691            Public Works Department                    Street Cleaning
# 46692              Inspectional Services                   Code Enforcement
# 46693            Public Works Department                    Street Cleaning
# 46694            Public Works Department                    Street Cleaning
# 46695              Inspectional Services                   Code Enforcement
# 46696            Mayor's 24 Hour Hotline        Employee & General Comments
# 46697            Public Works Department  Administrative & General Requests
#
#               ...          precinct land_usage  \
# 20777         ...              1901         R3
# 20778         ...              2007          E
# 20779         ...              2103        NaN
# 20780         ...               113         R4
# 20781         ...               113         R4
# 20782         ...               601          C
# 20783         ...               407          C
# 20784         ...              1308         R3
# 20785         ...              1606        NaN
# 20786         ...              2008        NaN
# 20787         ...              1310          C
# 20788         ...              1404          A
# 20789         ...              1705          E
# 20790         ...              1705        NaN
# 20791         ...              1818        NaN
# 20792         ...               704        NaN
# 20793         ...              1819         R1
# 20794         ...              1819          E
# 20795         ...              1813          C
# 20796         ...              1819          C
# 20797         ...               NaN        NaN
# 20798         ...               804        NaN
# 20799         ...              1714          A
# 20800         ...              1822         R1
# 20801         ...              2203         R3
# 20802         ...              2014          C
# 20803         ...              1714          A
# 20804         ...              1205         R3
# 20805         ...              1601        NaN
# 20806         ...               102        NaN
# ...           ...               ...        ...
# 46668         ...               706          E
# 46669         ...               307          E
# 46670         ...               705          C
# 46671         ...               103        NaN
# 46672         ...               903          A
# 46673         ...               801         RC
# 46674         ...              1708         R3
# 46675         ...              1606         CM
# 46676         ...               607        NaN
# 46677         ...               603         R1
# 46678         ...              2213         R2
# 46679         ...               105        NaN
# 46680         ...              1818          C
# 46681         ...               503         R1
# 46682         ...               503        NaN
# 46683         ...              1107         R3
# 46684         ...               201         EA
# 46685         ...               509         CM
# 46686         ...               503         R1
# 46687         ...              2213         R2
# 46688         ...               404         CM
# 46689         ...              1803         R3
# 46690         ...              1601         R3
# 46691         ...              1714         R1
# 46692         ...              1303         CL
# 46693         ...              1901         R2
# 46694         ...              1807          C
# 46695         ...              1803         R3
# 46696         ...               NaN        NaN
# 46697         ...              1803         R3
#
#                                LOCATION_STREET_NAME LOCATION_ZIPCODE  \
# 20777                                   27 Clive St             2130
# 20778                                1708 Centre St             2132
# 20779   INTERSECTION Commonwealth Ave & Harvard Ave              NaN
# 20780                             103-105 Leyden St             2128
# 20781                             103-105 Leyden St             2128
# 20782                           347-351 Congress St             2210
# 20783                                     36 Fenway             2215
# 20784                                  66 Romsey St             2125
# 20785         INTERSECTION Ashmont St & Bushnell St              NaN
# 20786      INTERSECTION Aldrich St & W Roxbury Pkwy              NaN
# 20787                        110-110 Savin Hill Ave             2125
# 20788                               143 Columbia Rd             2121
# 20789                              133 Southern Ave             2124
# 20790         INTERSECTION Millet St & Southern Ave              NaN
# 20791         INTERSECTION Hyde Park Ave & River St              NaN
# 20792                INTERSECTION F St & W Fifth St              NaN
# 20793                                 1892 River St             2136
# 20794                                 1916 River St             2136
# 20795                                 1285 River St             2136
# 20796                            1893-1897 River St             2136
# 20797                                           NaN              NaN
# 20798  INTERSECTION Harrison Ave & Melnea Cass Blvd              NaN
# 20799                                 1245 Adams St             2126
# 20800                                79 Deforest St             2136
# 20801                          16 Chestnut Hill Ave             2135
# 20802                                2000 Centre St             2132
# 20803                                 1245 Adams St             2126
# 20804                                 12 Catawba St             2119
# 20805         INTERSECTION Dorchester Ave & Park St              NaN
# 20806         INTERSECTION Cottage St & Maverick St              NaN
# ...                                             ...              ...
# 46668                              1190 Columbia Rd             2127
# 46669                       32-60 Paul Sullivan Way             2118
# 46670                                  69 Middle St             2127
# 46671          INTERSECTION Bremen St & S Bremen St              NaN
# 46672                            224 Northampton St             2118
# 46673                              700 Harrison Ave             2118
# 46674                              119 Armandine St             2124
# 46675                              591-593 Adams St             2124
# 46676            INTERSECTION Elkins St & Summer St              NaN
# 46677                                187 W Sixth St             2127
# 46678                             667 Washington St             2135
# 46679         INTERSECTION Chelsea St & Chelsea Ter              NaN
# 46680                            1300 Hyde Park Ave             2136
# 46681                                36 Pinckney St             2108
# 46682           INTERSECTION Branch St & Charles St              NaN
# 46683                                    39 Glen Rd             2130
# 46684                               39-49 Warren St             2129
# 46685                          333 Commonwealth Ave             2115
# 46686                                36 Pinckney St             2108
# 46687                             671 Washington St             2135
# 46688                              517 Columbus Ave             2118
# 46689                            1450 Blue Hill Ave             2126
# 46690                                493 Geneva Ave             2124
# 46691                              68 Clearwater Dr             2126
# 46692                           240 Mount Vernon St             2125
# 46693                          110-112 Paul Gore St             2130
# 46694                             456 Hyde Park Ave             2131
# 46695                            1450 Blue Hill Ave             2126
# 46696                                           NaN              NaN
# 46697                            1438 Blue Hill Ave             2126
#
#       Property_Type Property_ID  LATITUDE LONGITUDE                Source  \
# 20777       Address       34065   42.3170  -71.1085  Citizens Connect App
# 20778       Address      163076   42.2868  -71.1484      Constituent Call
# 20779  Intersection        3370   42.3501  -71.1309      Constituent Call
# 20780       Address       85737   42.3892  -71.0084  Citizens Connect App
# 20781       Address       85737   42.3892  -71.0084  Citizens Connect App
# 20782       Address       42105   42.3503  -71.0489      Constituent Call
# 20783       Address       57448   42.3454  -71.0902  Citizens Connect App
# 20784       Address      118181   42.3159  -71.0536      Constituent Call
# 20785  Intersection         661   42.2859  -71.0637  Citizens Connect App
# 20786  Intersection         250   42.2815  -71.1447  Citizens Connect App
# 20787       Address      156663   42.3118  -71.0537      Constituent Call
# 20788       Address      210368   42.3056  -71.0790      Constituent Call
# 20789       Address      129159   42.2897  -71.0780  Citizens Connect App
# 20790  Intersection        7305   42.2901  -71.0755  Citizens Connect App
# 20791  Intersection        6461   42.2558  -71.1241      Constituent Call
# 20792  Intersection        4726   42.3355  -71.0493      Constituent Call
# 20793       Address      116541   42.2428  -71.1425          Self Service
# 20794       Address      116550   42.2426  -71.1439          Self Service
# 20795       Address      116351   42.2559  -71.1246          Self Service
# 20796       Address      116542   42.2434  -71.1426          Self Service
# 20797           NaN         NaN   42.3594  -71.0587      Constituent Call
# 20798  Intersection        5673   42.3321  -71.0794  Citizens Connect App
# 20799       Address         580   42.2711  -71.0686      Constituent Call
# 20800       Address       47050   42.2685  -71.1303      Constituent Call
# 20801       Address      207206   42.3485  -71.1535      Constituent Call
# 20802       Address       27777   42.2817  -71.1576       City Worker App
# 20803       Address         580   42.2711  -71.0686      Constituent Call
# 20804       Address       26418   42.3197  -71.0834      Constituent Call
# 20805  Intersection        4141   42.2986  -71.0606      Constituent Call
# 20806  Intersection        3580   42.3683  -71.0347  Citizens Connect App
# ...             ...         ...       ...       ...                   ...
# 46668       Address      174024   42.3298  -71.0518  Citizens Connect App
# 46669       Address      108638   42.3429  -71.0640      Constituent Call
# 46670       Address       95233   42.3323  -71.0565          Self Service
# 46671  Intersection        1903   42.3685  -71.0389  Citizens Connect App
# 46672       Address      284625   42.3381  -71.0805  Citizens Connect App
# 46673       Address      172286   42.3383  -71.0707          Self Service
# 46674       Address        4942   42.2840  -71.0762      Constituent Call
# 46675       Address         841   42.2895  -71.0561          Self Service
# 46676  Intersection        4493   42.3392  -71.0355  Citizens Connect App
# 46677       Address      127995   42.3356  -71.0514  Citizens Connect App
# 46678       Address      330021   42.3517  -71.1702  Citizens Connect App
# 46679  Intersection        2870   42.3734  -71.0347  Citizens Connect App
# 46680       Address       77099   42.2541  -71.1241      Constituent Call
# 46681       Address      110672   42.3588  -71.0666  Citizens Connect App
# 46682  Intersection        1873   42.3567  -71.0697  Citizens Connect App
# 46683       Address       63938   42.3087  -71.1023  Citizens Connect App
# 46684       Address      143160   42.3734  -71.0611  Citizens Connect App
# 46685       Address       40229   42.3498  -71.0875  Citizens Connect App
# 46686       Address      110672   42.3588  -71.0666  Citizens Connect App
# 46687       Address      143671   42.3518  -71.1705  Citizens Connect App
# 46688       Address       35826   42.3422  -71.0801          Self Service
# 46689       Address       16281   42.2745  -71.0932      Constituent Call
# 46690       Address       63356   42.2989  -71.0641          Self Service
# 46691       Address       33730   42.2744  -71.0772  Citizens Connect App
# 46692       Address       98929   42.3190  -71.0450      Constituent Call
# 46693       Address      108519   42.3187  -71.1061  Citizens Connect App
# 46694       Address      157930   42.2850  -71.1187      Constituent Call
# 46695       Address      189748   42.2745  -71.0932          Self Service
# 46696           NaN         NaN   42.3594  -71.0587      Constituent Call
# 46697       Address       16276   42.2749  -71.0932      Constituent Call
#
#          Geocoded_Location
# 20777   (42.317, -71.1085)
# 20778  (42.2868, -71.1484)
# 20779  (42.3501, -71.1309)
# 20780  (42.3892, -71.0084)
# 20781  (42.3892, -71.0084)
# 20782  (42.3503, -71.0489)
# 20783  (42.3454, -71.0902)
# 20784  (42.3159, -71.0536)
# 20785  (42.2859, -71.0637)
# 20786  (42.2815, -71.1447)
# 20787  (42.3118, -71.0537)
# 20788   (42.3056, -71.079)
# 20789   (42.2897, -71.078)
# 20790  (42.2901, -71.0755)
# 20791  (42.2558, -71.1241)
# 20792  (42.3355, -71.0493)
# 20793  (42.2428, -71.1425)
# 20794  (42.2426, -71.1439)
# 20795  (42.2559, -71.1246)
# 20796  (42.2434, -71.1426)
# 20797  (42.3594, -71.0587)
# 20798  (42.3321, -71.0794)
# 20799  (42.2711, -71.0686)
# 20800  (42.2685, -71.1303)
# 20801  (42.3485, -71.1535)
# 20802  (42.2817, -71.1576)
# 20803  (42.2711, -71.0686)
# 20804  (42.3197, -71.0834)
# 20805  (42.2986, -71.0606)
# 20806  (42.3683, -71.0347)
# ...                    ...
# 46668  (42.3298, -71.0518)
# 46669   (42.3429, -71.064)
# 46670  (42.3323, -71.0565)
# 46671  (42.3685, -71.0389)
# 46672  (42.3381, -71.0805)
# 46673  (42.3383, -71.0707)
# 46674   (42.284, -71.0762)
# 46675  (42.2895, -71.0561)
# 46676  (42.3392, -71.0355)
# 46677  (42.3356, -71.0514)
# 46678  (42.3517, -71.1702)
# 46679  (42.3734, -71.0347)
# 46680  (42.2541, -71.1241)
# 46681  (42.3588, -71.0666)
# 46682  (42.3567, -71.0697)
# 46683  (42.3087, -71.1023)
# 46684  (42.3734, -71.0611)
# 46685  (42.3498, -71.0875)
# 46686  (42.3588, -71.0666)
# 46687  (42.3518, -71.1705)
# 46688  (42.3422, -71.0801)
# 46689  (42.2745, -71.0932)
# 46690  (42.2989, -71.0641)
# 46691  (42.2744, -71.0772)
# 46692    (42.319, -71.045)
# 46693  (42.3187, -71.1061)
# 46694   (42.285, -71.1187)
# 46695  (42.2745, -71.0932)
# 46696  (42.3594, -71.0587)
# 46697  (42.2749, -71.0932)
#
# [25921 rows x 33 columns]

# %% [markdown]
# Can you do the same thing, but only for the cases that are still remaining open? **(5 pts)**

# %%
# Write a code that also filters for open cases
still_open = boston[boston.CASE_STATUS == 'Open']
print still_open
# Out:
#        CASE_ENQUIRY_ID             OPEN_DT           TARGET_DT CLOSED_DT  \
# 2         101001240736 2015-01-01 00:25:36 2015-01-16 08:30:00       NaT
# 3         101001240740 2015-01-01 01:45:37                 NaT       NaT
# 7         101001240746 2015-01-01 03:46:15                 NaT       NaT
# 9         101001240750 2015-01-01 04:12:40                 NaT       NaT
# 11        101001240754 2015-01-01 07:27:13 2015-01-31 07:27:13       NaT
# 13        101001240757 2015-01-01 08:25:52 2015-01-09 08:30:00       NaT
# 14        101001240759 2015-01-01 08:35:44                 NaT       NaT
# 17        101001240762 2015-01-01 08:53:51 2015-01-31 08:53:51       NaT
# 24        101001240772 2015-01-01 09:33:25                 NaT       NaT
# 49        101001240807 2015-01-01 12:34:43                 NaT       NaT
# 50        101001240809 2015-01-01 12:37:13 2015-01-31 12:37:13       NaT
# 62        101001240822 2015-01-01 13:25:36 2015-03-10 08:30:00       NaT
# 75        101001240838 2015-01-01 14:25:24 2015-01-31 14:25:23       NaT
# 78        101001240842 2015-01-01 14:44:54 2015-01-31 14:44:54       NaT
# 81        101001240846 2015-01-01 15:03:22 2015-04-01 15:03:21       NaT
# 82        101001240847 2015-01-01 15:06:51 2015-03-10 08:30:00       NaT
# 89        101001240856 2015-01-01 16:15:33 2015-03-10 08:30:00       NaT
# 94        101001240863 2015-01-01 17:13:28 2015-01-31 17:13:28       NaT
# 100       101001240873 2015-01-01 18:31:59                 NaT       NaT
# 101       101001240874 2015-01-01 18:43:24 2015-01-16 08:30:00       NaT
# 102       101001240876 2015-01-01 19:04:03 2015-01-16 08:30:00       NaT
# 106       101001240881 2015-01-01 19:20:49                 NaT       NaT
# 107       101001240882 2015-01-01 19:25:55 2015-01-31 19:25:55       NaT
# 108       101001240883 2015-01-01 19:29:59 2015-05-01 19:29:59       NaT
# 117       101001240896 2015-01-01 22:11:51 2015-01-31 22:11:50       NaT
# 119       101001240898 2015-01-01 22:33:05 2015-03-10 08:30:00       NaT
# 120       101001240900 2015-01-01 23:01:33 2015-01-31 23:01:33       NaT
# 157       101001240953 2015-01-02 08:19:19                 NaT       NaT
# 161       101001240958 2015-01-02 08:22:05 2015-01-04 08:22:05       NaT
# 165       101001240968 2015-01-02 08:27:51 2015-02-01 08:27:51       NaT
# ...                ...                 ...                 ...       ...
# 46668     101001295365 2015-02-14 22:02:09 2015-02-19 08:30:00       NaT
# 46669     101001295366 2015-02-14 22:03:35                 NaT       NaT
# 46670     101001295367 2015-02-14 22:03:54 2015-02-24 08:30:00       NaT
# 46671     101001295368 2015-02-14 22:04:18 2015-02-19 08:30:00       NaT
# 46672     101001295370 2015-02-14 22:07:12 2015-02-19 08:30:00       NaT
# 46673     101001295371 2015-02-14 22:07:26 2015-02-19 08:30:00       NaT
# 46674     101001295372 2015-02-14 22:08:08 2015-03-16 22:08:07       NaT
# 46675     101001295374 2015-02-14 22:14:28 2015-02-24 08:30:00       NaT
# 46676     101001295375 2015-02-14 22:14:48 2015-02-24 08:30:00       NaT
# 46677     101001295376 2015-02-14 22:14:53 2015-02-19 08:30:00       NaT
# 46678     101001295379 2015-02-14 22:25:58 2015-02-19 08:30:00       NaT
# 46679     101001295380 2015-02-14 22:30:01 2015-02-19 08:30:00       NaT
# 46680     101001295381 2015-02-14 22:30:24 2015-03-03 08:30:00       NaT
# 46681     101001295382 2015-02-14 22:31:15 2015-03-03 08:30:00       NaT
# 46682     101001295384 2015-02-14 22:31:59 2015-03-03 08:30:00       NaT
# 46683     101001295385 2015-02-14 22:32:35 2015-03-03 08:30:00       NaT
# 46684     101001295386 2015-02-14 22:40:31 2015-03-03 08:30:00       NaT
# 46685     101001295388 2015-02-14 22:44:37 2015-03-03 08:30:00       NaT
# 46686     101001295389 2015-02-14 22:45:06 2015-03-03 08:30:00       NaT
# 46687     101001295391 2015-02-14 22:55:01 2015-02-19 08:30:00       NaT
# 46688     101001295392 2015-02-14 22:57:46 2015-02-19 08:30:00       NaT
# 46689     101001295393 2015-02-14 23:20:20                 NaT       NaT
# 46690     101001295394 2015-02-14 23:26:57 2015-02-24 08:30:00       NaT
# 46691     101001295395 2015-02-14 23:28:30 2015-02-19 08:30:00       NaT
# 46692     101001295396 2015-02-14 23:29:22 2015-02-24 08:30:00       NaT
# 46693     101001295400 2015-02-14 23:37:51 2015-02-19 08:30:00       NaT
# 46694     101001295401 2015-02-14 23:41:25                 NaT       NaT
# 46695     101001295402 2015-02-14 23:46:19 2015-02-24 08:30:00       NaT
# 46696     101001295406 2015-02-14 23:53:09 2015-03-03 08:30:00       NaT
# 46697     101001295407 2015-02-15 00:00:17                 NaT       NaT
#
#       OnTime_Status CASE_STATUS CLOSURE_REASON  \
# 2           OVERDUE        Open            NaN
# 3            ONTIME        Open            NaN
# 7            ONTIME        Open            NaN
# 9            ONTIME        Open            NaN
# 11          OVERDUE        Open            NaN
# 13          OVERDUE        Open            NaN
# 14           ONTIME        Open            NaN
# 17          OVERDUE        Open            NaN
# 24           ONTIME        Open            NaN
# 49           ONTIME        Open            NaN
# 50          OVERDUE        Open            NaN
# 62           ONTIME        Open            NaN
# 75          OVERDUE        Open            NaN
# 78          OVERDUE        Open            NaN
# 81           ONTIME        Open            NaN
# 82           ONTIME        Open            NaN
# 89           ONTIME        Open            NaN
# 94          OVERDUE        Open            NaN
# 100          ONTIME        Open            NaN
# 101         OVERDUE        Open            NaN
# 102             NaN        Open            NaN
# 106          ONTIME        Open            NaN
# 107         OVERDUE        Open            NaN
# 108          ONTIME        Open            NaN
# 117         OVERDUE        Open            NaN
# 119          ONTIME        Open            NaN
# 120         OVERDUE        Open            NaN
# 157          ONTIME        Open            NaN
# 161         OVERDUE        Open            NaN
# 165         OVERDUE        Open            NaN
# ...             ...         ...            ...
# 46668        ONTIME        Open            NaN
# 46669        ONTIME        Open            NaN
# 46670        ONTIME        Open            NaN
# 46671        ONTIME        Open            NaN
# 46672        ONTIME        Open            NaN
# 46673        ONTIME        Open            NaN
# 46674        ONTIME        Open            NaN
# 46675        ONTIME        Open            NaN
# 46676        ONTIME        Open            NaN
# 46677        ONTIME        Open            NaN
# 46678        ONTIME        Open            NaN
# 46679        ONTIME        Open            NaN
# 46680        ONTIME        Open            NaN
# 46681        ONTIME        Open            NaN
# 46682        ONTIME        Open            NaN
# 46683        ONTIME        Open            NaN
# 46684        ONTIME        Open            NaN
# 46685        ONTIME        Open            NaN
# 46686        ONTIME        Open            NaN
# 46687        ONTIME        Open            NaN
# 46688        ONTIME        Open            NaN
# 46689        ONTIME        Open            NaN
# 46690        ONTIME        Open            NaN
# 46691        ONTIME        Open            NaN
# 46692        ONTIME        Open            NaN
# 46693        ONTIME        Open            NaN
# 46694        ONTIME        Open            NaN
# 46695        ONTIME        Open            NaN
# 46696        ONTIME        Open            NaN
# 46697        ONTIME        Open            NaN
#
#                                            CASE_TITLE  \
# 2                                             PRINTED
# 3                                        Animal Found
# 7                                         Animal Lost
# 9                                        Animal Found
# 11                     Heat - Excessive  Insufficient
# 13                              Illegal Rooming House
# 14                                    Watermain Break
# 17                     Heat - Excessive  Insufficient
# 24                             Utility Casting Repair
# 49                                       Animal Found
# 50                     Heat - Excessive  Insufficient
# 62                                   Graffiti Removal
# 75                     Heat - Excessive  Insufficient
# 78                     Heat - Excessive  Insufficient
# 81                Maintenance Complaint - Residential
# 82                                   Graffiti Removal
# 89                                   Graffiti Removal
# 94                     Heat - Excessive  Insufficient
# 100                                      Animal Found
# 101           Street Light Outages/reallocated to DCR
# 102                                           PRINTED
# 106                                      Animal Found
# 107                    Heat - Excessive  Insufficient
# 108                  Unsatisfactory Living Conditions
# 117                    Heat - Excessive  Insufficient
# 119                           Graffiti: Ward 11  1109
# 120                    Heat - Excessive  Insufficient
# 157                                     Message Taken
# 161                                 Work w/out Permit
# 165                    Heat - Excessive  Insufficient
# ...                                               ...
# 46668                      Request for Pothole Repair
# 46669  Request for Snow Plowing (Emergency Responder)
# 46670                                    Snow Removal
# 46671                        Request for Snow Plowing
# 46672                        Request for Snow Plowing
# 46673                        Request for Snow Plowing
# 46674                  Heat - Excessive  Insufficient
# 46675                                    Snow Removal
# 46676                                    Snow Removal
# 46677                        Request for Snow Plowing
# 46678                        Request for Snow Plowing
# 46679                        Request for Snow Plowing
# 46680                            Street Light Outages
# 46681                            Street Light Outages
# 46682                            Street Light Outages
# 46683                                     Sign Repair
# 46684                            Street Light Outages
# 46685                            Street Light Outages
# 46686                            Street Light Outages
# 46687                        Request for Snow Plowing
# 46688                       Missed Trash: District 1C
# 46689                            Misc. Snow Complaint
# 46690                                    Snow Removal
# 46691                        Request for Snow Plowing
# 46692                                    Snow Removal
# 46693                        Request for Snow Plowing
# 46694  Request for Snow Plowing (Emergency Responder)
# 46695                                    Snow Removal
# 46696                          PublicWorks: Complaint
# 46697                            Misc. Snow Complaint
#
#                                  SUBJECT                             REASON  \
# 2                Public Works Department                      Street Lights
# 3                         Animal Control                      Animal Issues
# 7                         Animal Control                      Animal Issues
# 9                         Animal Control                      Animal Issues
# 11                 Inspectional Services                            Housing
# 13                 Inspectional Services                           Building
# 14       Boston Water & Sewer Commission                       Water Issues
# 17                 Inspectional Services                            Housing
# 24               Public Works Department                Highway Maintenance
# 49                        Animal Control                      Animal Issues
# 50                 Inspectional Services                            Housing
# 62                   Property Management                           Graffiti
# 75                 Inspectional Services                            Housing
# 78                 Inspectional Services                            Housing
# 81                 Inspectional Services                            Housing
# 82                   Property Management                           Graffiti
# 89                   Property Management                           Graffiti
# 94                 Inspectional Services                            Housing
# 100                       Animal Control                      Animal Issues
# 101              Public Works Department                      Street Lights
# 102              Public Works Department                      Street Lights
# 106                       Animal Control                      Animal Issues
# 107                Inspectional Services                            Housing
# 108                Inspectional Services                            Housing
# 117                Inspectional Services                            Housing
# 119                  Property Management                           Graffiti
# 120                Inspectional Services                            Housing
# 157                Inspectional Services                 Call Center Intake
# 161                Inspectional Services                           Building
# 165                Inspectional Services                            Housing
# ...                                  ...                                ...
# 46668            Public Works Department                Highway Maintenance
# 46669            Public Works Department                    Street Cleaning
# 46670              Inspectional Services                   Code Enforcement
# 46671            Public Works Department                    Street Cleaning
# 46672            Public Works Department                    Street Cleaning
# 46673            Public Works Department                    Street Cleaning
# 46674              Inspectional Services                            Housing
# 46675              Inspectional Services                   Code Enforcement
# 46676              Inspectional Services                   Code Enforcement
# 46677            Public Works Department                    Street Cleaning
# 46678            Public Works Department                    Street Cleaning
# 46679            Public Works Department                    Street Cleaning
# 46680            Public Works Department                      Street Lights
# 46681            Public Works Department                      Street Lights
# 46682            Public Works Department                      Street Lights
# 46683  Transportation - Traffic Division                    Signs & Signals
# 46684            Public Works Department                      Street Lights
# 46685            Public Works Department                      Street Lights
# 46686            Public Works Department                      Street Lights
# 46687            Public Works Department                    Street Cleaning
# 46688            Public Works Department                         Sanitation
# 46689            Public Works Department  Administrative & General Requests
# 46690              Inspectional Services                   Code Enforcement
# 46691            Public Works Department                    Street Cleaning
# 46692              Inspectional Services                   Code Enforcement
# 46693            Public Works Department                    Street Cleaning
# 46694            Public Works Department                    Street Cleaning
# 46695              Inspectional Services                   Code Enforcement
# 46696            Mayor's 24 Hour Hotline        Employee & General Comments
# 46697            Public Works Department  Administrative & General Requests
#
#               ...          precinct land_usage  \
# 2             ...               502          C
# 3             ...              2010         R4
# 7             ...              1611         R1
# 9             ...              1609         CD
# 11            ...               802        NaN
# 13            ...               509         R2
# 14            ...              2017          E
# 17            ...               903         EA
# 24            ...               306        NaN
# 49            ...              2203         R2
# 50            ...              1403          A
# 62            ...               510        NaN
# 75            ...               401         RC
# 78            ...              2104          A
# 81            ...              2104          A
# 82            ...               407          A
# 89            ...              1004        NaN
# 94            ...               802         CM
# 100           ...              1405          C
# 101           ...              2010         R1
# 102           ...              1908         CC
# 106           ...              1610          C
# 107           ...              1808          A
# 108           ...              1103          A
# 117           ...              1407          A
# 119           ...              1109         RC
# 120           ...              1710         R3
# 157           ...               601          I
# 161           ...               605         RC
# 165           ...              1304         R3
# ...           ...               ...        ...
# 46668         ...               706          E
# 46669         ...               307          E
# 46670         ...               705          C
# 46671         ...               103        NaN
# 46672         ...               903          A
# 46673         ...               801         RC
# 46674         ...              1708         R3
# 46675         ...              1606         CM
# 46676         ...               607        NaN
# 46677         ...               603         R1
# 46678         ...              2213         R2
# 46679         ...               105        NaN
# 46680         ...              1818          C
# 46681         ...               503         R1
# 46682         ...               503        NaN
# 46683         ...              1107         R3
# 46684         ...               201         EA
# 46685         ...               509         CM
# 46686         ...               503         R1
# 46687         ...              2213         R2
# 46688         ...               404         CM
# 46689         ...              1803         R3
# 46690         ...              1601         R3
# 46691         ...              1714         R1
# 46692         ...              1303         CL
# 46693         ...              1901         R2
# 46694         ...              1807          C
# 46695         ...              1803         R3
# 46696         ...               NaN        NaN
# 46697         ...              1803         R3
#
#                               LOCATION_STREET_NAME LOCATION_ZIPCODE  \
# 2                               145-151 Ipswich St             2215
# 3                               4833 Washington St             2132
# 7                                     246 Minot St             2124
# 9                                     730 Adams St             2122
# 11                              1744 Washington St             2118
# 13                                  50 Hereford St             2115
# 14                                95 Brook Farm Rd             2132
# 17                                    77 Camden St             2118
# 24                                   73 Tremont St             2108
# 49                                   27 Shepard St             2135
# 50                               522 Blue Hill Ave             2121
# 62     INTERSECTION Commonwealth Ave & Charlesgate              NaN
# 75                                282 Columbus Ave             2116
# 78                                   72 Gardner St             2134
# 81                                   72 Gardner St             2134
# 82                                 52 Westland Ave             2115
# 89        INTERSECTION Huntington Ave & Jamaicaway              NaN
# 94                               11-25 E Newton St             2118
# 100                              834-842 Morton St             2124
# 101                            19 Bellevue Hill Rd             2132
# 102                              701-703 Centre St             2130
# 106                   961 William T Morrissey Blvd             2122
# 107                              950 Canterbury St             2131
# 108                                 247 Walnut Ave             2119
# 117                                    31 Wales St             2124
# 119                                 86-90 South St             2130
# 120                                    6 Nelson St             2124
# 157                              311-319 Summer St             2210
# 161                            649-649H E Broadway             2127
# 165                                  21 Sargent St             2125
# ...                                            ...              ...
# 46668                             1190 Columbia Rd             2127
# 46669                      32-60 Paul Sullivan Way             2118
# 46670                                 69 Middle St             2127
# 46671         INTERSECTION Bremen St & S Bremen St              NaN
# 46672                           224 Northampton St             2118
# 46673                             700 Harrison Ave             2118
# 46674                             119 Armandine St             2124
# 46675                             591-593 Adams St             2124
# 46676           INTERSECTION Elkins St & Summer St              NaN
# 46677                               187 W Sixth St             2127
# 46678                            667 Washington St             2135
# 46679        INTERSECTION Chelsea St & Chelsea Ter              NaN
# 46680                           1300 Hyde Park Ave             2136
# 46681                               36 Pinckney St             2108
# 46682          INTERSECTION Branch St & Charles St              NaN
# 46683                                   39 Glen Rd             2130
# 46684                              39-49 Warren St             2129
# 46685                         333 Commonwealth Ave             2115
# 46686                               36 Pinckney St             2108
# 46687                            671 Washington St             2135
# 46688                             517 Columbus Ave             2118
# 46689                           1450 Blue Hill Ave             2126
# 46690                               493 Geneva Ave             2124
# 46691                             68 Clearwater Dr             2126
# 46692                          240 Mount Vernon St             2125
# 46693                         110-112 Paul Gore St             2130
# 46694                            456 Hyde Park Ave             2131
# 46695                           1450 Blue Hill Ave             2126
# 46696                                          NaN              NaN
# 46697                           1438 Blue Hill Ave             2126
#
#       Property_Type Property_ID  LATITUDE LONGITUDE                Source  \
# 2           Address      157262   42.3474  -71.0944  Citizens Connect App
# 3           Address      331760   42.2711  -71.1464      Constituent Call
# 7           Address       96119   42.2834  -71.0576      Constituent Call
# 9           Address         949   42.2847  -71.0550      Constituent Call
# 11          Address      351061   42.3594  -71.0587      Constituent Call
# 13          Address       73014   42.3490  -71.0856          Self Service
# 14          Address       21939   42.2915  -71.1683      Constituent Call
# 17          Address      201313   42.3375  -71.0804      Constituent Call
# 24          Address      347781   42.3594  -71.0587       City Worker App
# 49          Address      126686   42.3470  -71.1507      Constituent Call
# 50          Address      190031   42.3064  -71.0841      Constituent Call
# 62     Intersection        3390   42.3488  -71.0923  Citizens Connect App
# 75          Address      211724   42.3469  -71.0736      Constituent Call
# 78          Address      239609   42.3540  -71.1273          Self Service
# 81          Address      239609   42.3540  -71.1273          Self Service
# 82          Address      148492   42.3434  -71.0882  Citizens Connect App
# 89     Intersection        6416   42.3319  -71.1130  Citizens Connect App
# 94          Address      102338   42.3382  -71.0731      Constituent Call
# 100         Address       97809   42.2816  -71.0866      Constituent Call
# 101         Address       13980   42.2779  -71.1427  Citizens Connect App
# 102         Address       28167   42.3116  -71.1146  Citizens Connect App
# 106         Address      149940   42.2912  -71.0475      Constituent Call
# 107         Address      201733   42.2785  -71.1172      Constituent Call
# 108         Address      327372   42.3181  -71.0913      Constituent Call
# 117         Address      326017   42.2969  -71.0850      Constituent Call
# 119         Address      128985   42.3067  -71.1151  Citizens Connect App
# 120         Address      281215   42.2832  -71.0829      Constituent Call
# 157         Address      170076   42.3493  -71.0489      Constituent Call
# 161         Address       21097   42.3354  -71.0387      Constituent Call
# 165         Address      306492   42.3161  -71.0741      Constituent Call
# ...             ...         ...       ...       ...                   ...
# 46668       Address      174024   42.3298  -71.0518  Citizens Connect App
# 46669       Address      108638   42.3429  -71.0640      Constituent Call
# 46670       Address       95233   42.3323  -71.0565          Self Service
# 46671  Intersection        1903   42.3685  -71.0389  Citizens Connect App
# 46672       Address      284625   42.3381  -71.0805  Citizens Connect App
# 46673       Address      172286   42.3383  -71.0707          Self Service
# 46674       Address        4942   42.2840  -71.0762      Constituent Call
# 46675       Address         841   42.2895  -71.0561          Self Service
# 46676  Intersection        4493   42.3392  -71.0355  Citizens Connect App
# 46677       Address      127995   42.3356  -71.0514  Citizens Connect App
# 46678       Address      330021   42.3517  -71.1702  Citizens Connect App
# 46679  Intersection        2870   42.3734  -71.0347  Citizens Connect App
# 46680       Address       77099   42.2541  -71.1241      Constituent Call
# 46681       Address      110672   42.3588  -71.0666  Citizens Connect App
# 46682  Intersection        1873   42.3567  -71.0697  Citizens Connect App
# 46683       Address       63938   42.3087  -71.1023  Citizens Connect App
# 46684       Address      143160   42.3734  -71.0611  Citizens Connect App
# 46685       Address       40229   42.3498  -71.0875  Citizens Connect App
# 46686       Address      110672   42.3588  -71.0666  Citizens Connect App
# 46687       Address      143671   42.3518  -71.1705  Citizens Connect App
# 46688       Address       35826   42.3422  -71.0801          Self Service
# 46689       Address       16281   42.2745  -71.0932      Constituent Call
# 46690       Address       63356   42.2989  -71.0641          Self Service
# 46691       Address       33730   42.2744  -71.0772  Citizens Connect App
# 46692       Address       98929   42.3190  -71.0450      Constituent Call
# 46693       Address      108519   42.3187  -71.1061  Citizens Connect App
# 46694       Address      157930   42.2850  -71.1187      Constituent Call
# 46695       Address      189748   42.2745  -71.0932          Self Service
# 46696           NaN         NaN   42.3594  -71.0587      Constituent Call
# 46697       Address       16276   42.2749  -71.0932      Constituent Call
#
#          Geocoded_Location
# 2      (42.3474, -71.0944)
# 3      (42.2711, -71.1464)
# 7      (42.2834, -71.0576)
# 9       (42.2847, -71.055)
# 11     (42.3594, -71.0587)
# 13      (42.349, -71.0856)
# 14     (42.2915, -71.1683)
# 17     (42.3375, -71.0804)
# 24     (42.3594, -71.0587)
# 49      (42.347, -71.1507)
# 50     (42.3064, -71.0841)
# 62     (42.3488, -71.0923)
# 75     (42.3469, -71.0736)
# 78      (42.354, -71.1273)
# 81      (42.354, -71.1273)
# 82     (42.3434, -71.0882)
# 89      (42.3319, -71.113)
# 94     (42.3382, -71.0731)
# 100    (42.2816, -71.0866)
# 101    (42.2779, -71.1427)
# 102    (42.3116, -71.1146)
# 106    (42.2912, -71.0475)
# 107    (42.2785, -71.1172)
# 108    (42.3181, -71.0913)
# 117     (42.2969, -71.085)
# 119    (42.3067, -71.1151)
# 120    (42.2832, -71.0829)
# 157    (42.3493, -71.0489)
# 161    (42.3354, -71.0387)
# 165    (42.3161, -71.0741)
# ...                    ...
# 46668  (42.3298, -71.0518)
# 46669   (42.3429, -71.064)
# 46670  (42.3323, -71.0565)
# 46671  (42.3685, -71.0389)
# 46672  (42.3381, -71.0805)
# 46673  (42.3383, -71.0707)
# 46674   (42.284, -71.0762)
# 46675  (42.2895, -71.0561)
# 46676  (42.3392, -71.0355)
# 46677  (42.3356, -71.0514)
# 46678  (42.3517, -71.1702)
# 46679  (42.3734, -71.0347)
# 46680  (42.2541, -71.1241)
# 46681  (42.3588, -71.0666)
# 46682  (42.3567, -71.0697)
# 46683  (42.3087, -71.1023)
# 46684  (42.3734, -71.0611)
# 46685  (42.3498, -71.0875)
# 46686  (42.3588, -71.0666)
# 46687  (42.3518, -71.1705)
# 46688  (42.3422, -71.0801)
# 46689  (42.2745, -71.0932)
# 46690  (42.2989, -71.0641)
# 46691  (42.2744, -71.0772)
# 46692    (42.319, -71.045)
# 46693  (42.3187, -71.1061)
# 46694   (42.285, -71.1187)
# 46695  (42.2745, -71.0932)
# 46696  (42.3594, -71.0587)
# 46697  (42.2749, -71.0932)
#
# [11557 rows x 33 columns]

# %% [markdown]
# Great! Now, let's check all the different values of the column `CASE_TITLE` together with their counts **(5 pts)**

# %%
# Write code that prints the different values of the column 'CASE_TITLE'
# and the count for the occurencies of each value in the boston dataframe
# Helper to print the dictionary
from pprint import pprint
titles = {}
for idx, row in boston.iterrows():
    title = row.CASE_TITLE
    if title in titles:
        titles[title] += 1
    if not (title in titles):
        titles[title] = 1
pprint(titles)
# Out:
# {nan: 19,
#  '1/2 out////printed': 1,
#  '200 a street////printed': 1,
#  'Abandoned Bicycle': 17,
#  'Abandoned Building': 8,
#  'Abandoned Vehicles': 225,
#  'Aircraft Noise Disturbance': 2,
#  'Alert Boston': 72,
#  'Animal Found': 33,
#  'Animal Generic Request': 202,
#  'Animal Lost': 24,
#  'Animal Noise Disturbances': 5,
#  'Automotive Noise Disturbance': 1,
#  'BHA Notification': 1,
#  'BTDT: Comment': 20,
#  'BTDT: Complaint': 63,
#  'BTDT: Compliment': 3,
#  'BWSC Pothole': 3,
#  'BWSC: Sanitary Sewer Overflow (SSO)': 7,
#  'BWSC: Water Main Break': 9,
#  'BWSC: Water Main Shutoff': 5,
#  'Bed Bugs': 34,
#  'Beethoven Elementary': 1,
#  'Big Buildings Recycling (INTERNAL)': 5,
#  'Blackstone Elementary': 1,
#  'Boston Bikes: Bikes - General; Complaint': 1,
#  'Boston Bikes: Bikes - General; Enforcement': 2,
#  'Boston Latin School': 1,
#  'Breathe Easy': 30,
#  'Bridge Maintenance': 1,
#  'Building Inspection Request': 160,
#  'Burke High School': 1,
#  'CE Collection': 1,
#  'Call Log': 89,
#  'Carbon Monoxide': 2,
#  'Catchbasin': 43,
#  'Cemetery Maintenance Request': 2,
#  'Charlestown High School': 1,
#  'Christmas Tree Trash: District 04': 1,
#  'Chronic Dampness/Mold': 54,
#  'City/State Snow Issues': 328,
#  'Clap Elementary': 1,
#  'Comments on City Policy  D10': 1,
#  'Compliment': 1,
#  'Condon Elementary': 5,
#  'Conservatory Lab Charter': 1,
#  'Construction Debris': 8,
#  'Contractor Complaint  D10': 1,
#  'Contractor Complaints': 122,
#  'Contractors Complaint': 39,
#  'Cross Metering - Sub-Metering': 36,
#  'Downed Wire': 3,
#  'Dudley Street Neighborhood School': 1,
#  'Edison K-8': 2,
#  'Edward Brooke Charter Sch 2 (SB)': 2,
#  'Egress': 18,
#  'Electrical': 73,
#  'Electrical Safety: Person/Pet Shocked': 2,
#  'Electrical Safety: Person/Pet Shocked////printed': 1,
#  'Eliot K-8': 1,
#  'Eliot Pearson School': 1,
#  'Ellis Elementary': 3,
#  'Empty Litter Basket': 489,
#  'Equipment Repair': 24,
#  'Equipment Repair: Hemenway Playground': 1,
#  'Everett Elementary': 2,
#  'Exceeding Terms of Permit': 8,
#  'Fence: Boston Common Equipment Repair': 1,
#  'Fenway High': 1,
#  'Fire': 38,
#  'Fire Department': 319,
#  'Fire Hydrant': 26,
#  'Fire in Food Establishment': 3,
#  'Fire light out  ( Contractor)': 1,
#  'Fire: Hazmat': 2,
#  'Fire: Odor of Gas': 2,
#  'Fire: Other': 6,
#  'Fire: Technical Rescue': 1,
#  'Food Alert - Confirmed': 5,
#  'Food Alert - Unconfirmed': 17,
#  'Front Desk Interactions': 240,
#  'General Comments For An Employee': 8,
#  'General Comments For a Program or Policy': 86,
#  'General Lighting Reques//PRINTED': 1,
#  'General Lighting Request': 14,
#  'General Lighting Request    // SENT TO MAVERICK //': 1,
#  'General Lighting Request  (Contractor)': 2,
#  'General Lighting Request  SENT TO MAVERICK': 1,
#  'General Lighting Request ( COntractor )': 1,
#  'General Lighting Request ( Contactor ranger found )': 1,
#  'General Lighting Request ( Contractor': 1,
#  'General Lighting Request (contractor)': 2,
#  'General Lighting Request (contractor) Ranger found': 1,
#  'General Lighting Request Sent To Contractor': 1,
#  'General Lighting Request///PRINTED': 1,
#  'General Lighting Request///See Note': 1,
#  'General Lighting Request//PRINTED': 6,
#  'General Lighting Request//duplicate of #1250302//sent to contractor': 1,
#  'General Lighting Request//printed': 2,
#  'General Lighting Request//sent to contractor queue': 4,
#  'General Lighting Request/PRINTED': 1,
#  'General Request': 21,
#  'General School Request': 34,
#  'General Traffic Engineering Request': 4,
#  'Generic Noise Disturbance': 7,
#  'Graffiti Removal': 186,
#  'Graffiti: 04  0409  Other': 1,
#  'Graffiti: 05  0502  Other': 2,
#  'Graffiti: 05  0508': 1,
#  'Graffiti: 06  0606  Racial': 1,
#  'Graffiti: 09  0903': 1,
#  'Graffiti: 21    Other': 1,
#  'Graffiti: 22  2201  Other': 1,
#  'Graffiti: Ward 1  0102': 1,
#  'Graffiti: Ward 1  0104': 1,
#  'Graffiti: Ward 1  0105  Other': 1,
#  'Graffiti: Ward 1  0106': 1,
#  'Graffiti: Ward 1  0106  Gang': 2,
#  'Graffiti: Ward 1  0107  Other': 1,
#  'Graffiti: Ward 1  0110  Gang': 1,
#  'Graffiti: Ward 1  0110  Other': 1,
#  'Graffiti: Ward 10  1002': 1,
#  'Graffiti: Ward 10  1002  Other': 1,
#  'Graffiti: Ward 10  1006  Other': 1,
#  'Graffiti: Ward 10  1008  Other': 1,
#  'Graffiti: Ward 11  1104  Gang': 2,
#  'Graffiti: Ward 11  1105': 1,
#  'Graffiti: Ward 11  1105  Gang': 1,
#  'Graffiti: Ward 11  1106': 1,
#  'Graffiti: Ward 11  1106  Other': 1,
#  'Graffiti: Ward 11  1109': 1,
#  'Graffiti: Ward 13  1307  Other': 1,
#  'Graffiti: Ward 13  1310': 1,
#  'Graffiti: Ward 13  1310  Other': 1,
#  'Graffiti: Ward 14  1401  Gang': 1,
#  'Graffiti: Ward 16  1601': 1,
#  'Graffiti: Ward 16  1601  Other': 1,
#  'Graffiti: Ward 16  1607  Other': 1,
#  'Graffiti: Ward 16  1608': 1,
#  'Graffiti: Ward 16  1608  Other': 5,
#  'Graffiti: Ward 18  1808': 1,
#  'Graffiti: Ward 18  1810  Other': 1,
#  'Graffiti: Ward 18  1816  Other': 1,
#  'Graffiti: Ward 19  1904': 1,
#  'Graffiti: Ward 19  1913': 1,
#  'Graffiti: Ward 19  1913  Profane Text': 2,
#  'Graffiti: Ward 2  0201': 2,
#  'Graffiti: Ward 2  0201  Other': 4,
#  'Graffiti: Ward 2  0206  Other': 1,
#  'Graffiti: Ward 20  2005  Other': 1,
#  'Graffiti: Ward 20  2016  Profane Text': 1,
#  'Graffiti: Ward 21  2103  Other': 1,
#  'Graffiti: Ward 21  2104': 1,
#  'Graffiti: Ward 21  2104  Other': 1,
#  'Graffiti: Ward 21  2106  Profane Text': 1,
#  'Graffiti: Ward 22  2201  Other': 5,
#  'Graffiti: Ward 22  2202': 4,
#  'Graffiti: Ward 22  2202  Other': 3,
#  'Graffiti: Ward 22  2203  Other': 1,
#  'Graffiti: Ward 22  2205': 1,
#  'Graffiti: Ward 3  0301': 2,
#  'Graffiti: Ward 3  0302': 1,
#  'Graffiti: Ward 3  0306  Gang': 1,
#  'Graffiti: Ward 3  0306  Other': 1,
#  'Graffiti: Ward 3  0308': 2,
#  'Graffiti: Ward 3  0308  Other': 1,
#  'Graffiti: Ward 4  0401': 1,
#  'Graffiti: Ward 4  0403': 1,
#  'Graffiti: Ward 4  0410  Other': 1,
#  'Graffiti: Ward 5  0501': 2,
#  'Graffiti: Ward 5  0501  Profane Text': 1,
#  'Graffiti: Ward 5  0502  Other': 3,
#  'Graffiti: Ward 5  0503': 1,
#  'Graffiti: Ward 5  0508': 2,
#  'Graffiti: Ward 5  0509': 1,
#  'Graffiti: Ward 6  0601': 1,
#  'Graffiti: Ward 6  0604': 1,
#  'Graffiti: Ward 6  0609': 1,
#  'Graffiti: Ward 8  0802': 1,
#  'Graffiti: Ward 8  0802  Other': 2,
#  'Graffiti: Ward 8  0803  Other': 1,
#  'Greenwood Sarah K-8': 1,
#  'Ground Maintenance': 37,
#  'Ground Maintenance:': 2,
#  'Ground Maintenance: --------------------': 3,
#  'Ground Maintenance: --Not in list--': 1,
#  'Ground Maintenance: Almont Park/Hunt Playground': 2,
#  'Ground Maintenance: Almont Park/Hunt Playground  Almont Park': 1,
#  'Ground Maintenance: Back Bay Fens': 2,
#  'Ground Maintenance: Bennington St. Cemetery': 4,
#  'Ground Maintenance: Billings Field': 1,
#  'Ground Maintenance: Blackstone Square': 3,
#  'Ground Maintenance: Blackstone Square  Blackstone Square': 3,
#  'Ground Maintenance: Boston Common': 5,
#  'Ground Maintenance: Boston Common  Boston Common': 3,
#  'Ground Maintenance: Brighton Square': 2,
#  'Ground Maintenance: Brophy Park': 3,
#  'Ground Maintenance: Brophy Park  Brophy Park': 1,
#  'Ground Maintenance: Buckley Playground': 1,
#  'Ground Maintenance: Bunker Hill Monument': 1,
#  'Ground Maintenance: Cassidy Playground  Cassidy Playground': 1,
#  'Ground Maintenance: Chandler Pond  Chandler Pond': 1,
#  'Ground Maintenance: Charter St. Park': 1,
#  'Ground Maintenance: Chester Park': 3,
#  "Ground Maintenance: Childrens Park  Children's Park": 1,
#  'Ground Maintenance: Christopher Columbus Park  Christopher Columbus Park': 2,
#  'Ground Maintenance: Clarendon St. Totlot': 5,
#  'Ground Maintenance: Clifford Playground': 1,
#  'Ground Maintenance: Clifford Playground  Clifford Playground': 1,
#  'Ground Maintenance: Commonwealth Ave.': 1,
#  'Ground Maintenance: Commonwealth Avenue Mall': 2,
#  'Ground Maintenance: Copley Square  Copley Square': 1,
#  'Ground Maintenance: Cutillo Park': 1,
#  'Ground Maintenance: DeFilippo Playground': 1,
#  'Ground Maintenance: DeFilippo Playground  DeFilippo Playground': 1,
#  'Ground Maintenance: Doherty Playground': 1,
#  'Ground Maintenance: Dorchester Park': 2,
#  'Ground Maintenance: Dudley Town Common': 2,
#  'Ground Maintenance: East Boston Greenway': 3,
#  'Ground Maintenance: Edgerly Road Playground': 2,
#  'Ground Maintenance: Edgeworth St. Play Area  Edwards Playground': 2,
#  'Ground Maintenance: Eliot Burying Ground': 1,
#  'Ground Maintenance: Fallon Field': 1,
#  'Ground Maintenance: Flaherty Playground': 1,
#  'Ground Maintenance: Forbes St. Playground': 1,
#  'Ground Maintenance: Forest Hills Cemetery': 1,
#  'Ground Maintenance: Franklin Park': 3,
#  'Ground Maintenance: Franklin Park  Franklin Park Zoo': 1,
#  'Ground Maintenance: Franklin Park  William J. Devine Golf Course': 4,
#  'Ground Maintenance: Geneva Ave. Cliffs': 1,
#  'Ground Maintenance: Hannon Playground': 1,
#  'Ground Maintenance: Hardiman Playground  Hardiman Playground': 1,
#  'Ground Maintenance: Hayes Park': 1,
#  'Ground Maintenance: Hayes Park  Hayes Park': 1,
#  'Ground Maintenance: Healy Playground': 1,
#  'Ground Maintenance: Healy Playground  BCYF Flaherty Pool': 1,
#  'Ground Maintenance: Hiscock Park': 1,
#  'Ground Maintenance: Hobart Park  Hobart Park': 1,
#  'Ground Maintenance: Hynes Playground': 3,
#  'Ground Maintenance: Jamaica Pond': 4,
#  'Ground Maintenance: Jamaica Pond  Jamaica Pond Park': 1,
#  'Ground Maintenance: Jeep Jones Park': 2,
#  'Ground Maintenance: Jeep Jones Park  Jeep Jones Park': 2,
#  'Ground Maintenance: John Eliot Square': 2,
#  'Ground Maintenance: Lambert Ave. Playground  Lambert Avenue Playground': 1,
#  'Ground Maintenance: Marcella/Connolly Park': 1,
#  'Ground Maintenance: Martin Luther King Boulevard': 1,
#  'Ground Maintenance: McCarthy Playground': 2,
#  'Ground Maintenance: McCarthy Playground  Edwards Playground': 1,
#  'Ground Maintenance: McKinney Playground': 1,
#  'Ground Maintenance: McLaughlin Playground  McLaughlin Playground': 1,
#  'Ground Maintenance: Melnea Cass Boulevard': 1,
#  'Ground Maintenance: Moynihan Playground': 1,
#  'Ground Maintenance: Msgr. Francis A. Ryan Park': 1,
#  'Ground Maintenance: Myrtle Street Play Area': 2,
#  'Ground Maintenance: Non - Parks Facility': 1,
#  'Ground Maintenance: Non - Parks Facility  William J. Devine Golf Course': 1,
#  'Ground Maintenance: Peters Park': 7,
#  "Ground Maintenance: Peters Park  Peter's Park": 5,
#  'Ground Maintenance: Porzio Park': 1,
#  'Ground Maintenance: Porzio Park  Porzio Park I': 2,
#  'Ground Maintenance: Praught Field': 1,
#  'Ground Maintenance: Public Garden': 1,
#  'Ground Maintenance: Public Garden  Public Garden': 1,
#  'Ground Maintenance: Quincy Street Play Area': 1,
#  'Ground Maintenance: Ramsay Park/Jim Rice Field': 1,
#  'Ground Maintenance: Ramsay Park/Jim Rice Field  Ramsay Park': 2,
#  'Ground Maintenance: Richardson Square': 1,
#  'Ground Maintenance: Ringer Playground': 7,
#  'Ground Maintenance: Ringer Playground  Ringer Playground': 2,
#  'Ground Maintenance: Ringgold Park': 2,
#  'Ground Maintenance: Rogers Park': 9,
#  'Ground Maintenance: Ronan Park': 2,
#  'Ground Maintenance: Ronan Park  Ronan Park': 1,
#  'Ground Maintenance: Rose Garden': 1,
#  'Ground Maintenance: Rutherford Avenue Playground': 1,
#  'Ground Maintenance: Rutland Square': 1,
#  'Ground Maintenance: Ryan Play Area': 1,
#  'Ground Maintenance: Ryan Playground  Ryan Playground': 1,
#  'Ground Maintenance: Savin Hill Park': 1,
#  'Ground Maintenance: South End Library Park': 1,
#  'Ground Maintenance: Southwest Boston Garden Club': 1,
#  'Ground Maintenance: Stony Brook Reservation': 2,
#  'Ground Maintenance: Symphony Community Park  Symphony Community Park': 1,
#  'Ground Maintenance: Town Field/Doherty': 1,
#  'Ground Maintenance: Tremont/Arlington Park': 2,
#  'Ground Maintenance: Trotter School Playground': 1,
#  'Ground Maintenance: Truman Highway': 1,
#  'Ground Maintenance: Union Park': 1,
#  'Ground Maintenance: Walker Playground': 1,
#  'Ground Maintenance: Walnut Park': 1,
#  'Ground Maintenance: Warren Gardens/Gendrot Trust  Warren Gardens/Gendrot Trust': 1,
#  'Ground Maintenance: Woodhaven': 1,
#  'Hale Elementary': 1,
#  'Haley Elementary': 2,
#  'Haynes EEC': 1,
#  'Heat - Excessive  Insufficient': 518,
#  'Heat/Fuel Assistance': 5,
#  'Hennigan Elementary': 1,
#  'Highway Maintenance': 19,
#  'Holmes Elementary': 1,
#  'Housing Discrimination Intake Form': 12,
#  'Hurley K-8': 1,
#  'Illegal Auto Body Shop': 6,
#  'Illegal Dumping': 125,
#  'Illegal Occupancy': 38,
#  'Illegal Posting of Signs': 11,
#  'Illegal Rooming House': 15,
#  'Illegal Vending': 8,
#  'Improper Storage': 3,
#  'Improper Storage of Trash (Barrels)': 203,
#  'Install New Lighting//duplicate case//sent to contractor': 1,
#  'Jackson/Mann K-8': 4,
#  'Knockdown Replacement': 3,
#  'Knockdown Replacement    PRINTED': 2,
#  'Knockdown Replacement   PRINTED': 2,
#  'Knockdown Replacement  PRINTED': 4,
#  'Knockdown Replacement///printed': 1,
#  'Knockdown Replacement//PRINTED': 4,
#  'LAMP #N1378020  156 Weld St/sent': 1,
#  'LAMP #N5472XXX Congress St. @ Dot. Ave./sent': 1,
#  'Lead': 7,
#  'Light replacement due to knocked down utility poles': 1,
#  'Lighting/Electrical:': 1,
#  'Lights on Constant//sent to maverick queue': 1,
#  'Litter Basket Maintenance': 8,
#  'Loud Parties/Music/People': 2,
#  'Lyndon K-8': 1,
#  'MBTA': 233,
#  'MVA: General': 1,
#  'Maintenance - Homeowner': 10,
#  'Maintenance Complaint - Residential': 66,
#  'Major System Failure': 9,
#  'Major System Failure  / PRINTED //': 1,
#  'Major System Failure  //  PRINTED //': 1,
#  'Major System Failure  // PRINTED //': 1,
#  'Major System Failure ( Contractor )': 1,
#  'Major System Failure // PRINTED //': 2,
#  'Major System Failure //PRINTED //': 1,
#  'Major System Failure PRINTED': 1,
#  'Major System Failure/////printed': 1,
#  'Major System Failure////printed': 11,
#  'Major System Failure////suspended': 2,
#  'Major System Failure///change button eye': 1,
#  'Major System Failure///printed': 1,
#  'Major System Failure///printed ///crew at scene 1/23/15': 1,
#  'Major System Failure///printed///duplicate': 1,
#  'Major System Failure//PRINTED //': 1,
#  'Major System Failure//duplicate of #1249447': 1,
#  'Major System Failure//printed': 4,
#  'Major System Failure//printed - gave to Dan Pl.': 1,
#  'Major System Failure//printed out duplicate': 1,
#  'Major System Failure//sent to contractor queue': 1,
#  'Major System Failure/LAMP #N1454015  85 Austin St/sent': 1,
#  'Major System Failure/printed': 1,
#  'Match Community Day Charter School': 1,
#  'Mattahunt Elementary': 4,
#  'Mechanical': 2,
#  'Message Taken': 273,
#  'Metrolist Survey': 3,
#  'Mice Infestation - Residential': 37,
#  'Misc. Snow Complaint': 768,
#  'Misc.: Public Garden: Park Improvement: Public Garden': 1,
#  'Misc.: Ronan Park Equipment Repair': 1,
#  'Misc.:Back Bay Fens:Park Improvement:': 1,
#  'Misc.:Boston Common: granite stone reset': 1,
#  'Missed " Trash: District 07': 1,
#  'Missed "Other" Trash: District': 2,
#  'Missed "Other" Trash: District 02': 7,
#  'Missed "Other" Trash: District 03': 15,
#  'Missed "Other" Trash: District 04': 9,
#  'Missed "Other" Trash: District 05': 4,
#  'Missed "Other" Trash: District 06': 2,
#  'Missed "Other" Trash: District 07': 8,
#  'Missed "Other" Trash: District 09': 10,
#  'Missed "Other" Trash: District 10A': 2,
#  'Missed "Other" Trash: District 10B': 4,
#  'Missed "Other" Trash: District 1A': 1,
#  'Missed "Other" Trash: District 1B': 3,
#  'Missed "Other" Trash: District 1C': 11,
#  'Missed "Other" Trash: No Location': 1,
#  'Missed "Tree &Trash: District 03': 1,
#  'Missed Bulk Item Pickup: District 02': 4,
#  'Missed Bulk Item Pickup: District 03': 3,
#  'Missed Bulk Item Pickup: District 04': 3,
#  'Missed Bulk Item Pickup: District 05': 5,
#  'Missed Bulk Item Pickup: District 06': 4,
#  'Missed Bulk Item Pickup: District 07': 7,
#  'Missed Bulk Item Pickup: District 08': 7,
#  'Missed Bulk Item Pickup: District 09': 2,
#  'Missed Bulk Item Pickup: District 10B': 1,
#  'Missed Bulk Item Pickup: District 1A': 4,
#  'Missed Bulk Item Pickup: District 1B': 1,
#  'Missed Bulk Item Pickup: District 1C': 2,
#  'Missed Leaf or Yard Trash: District 02': 2,
#  'Missed Leaf or Yard Trash: District 03': 4,
#  'Missed Leaf or Yard Trash: District 04': 3,
#  'Missed Leaf or Yard Trash: District 05': 2,
#  'Missed Leaf or Yard Trash: District 06': 2,
#  'Missed Leaf or Yard Trash: District 07': 5,
#  'Missed Leaf or Yard Trash: District 08': 1,
#  'Missed Leaf or Yard Trash: District 09': 1,
#  'Missed Leaf or Yard Trash: District 10B': 2,
#  'Missed Leaf or Yard Trash: District 1A': 1,
#  'Missed Leaf or Yard Trash: District 1B': 1,
#  'Missed Leaf or Yard Trash: District 1C': 2,
#  'Missed Recycling and Trash: District 07': 1,
#  'Missed Recycling: District': 6,
#  'Missed Recycling: District 02': 162,
#  'Missed Recycling: District 03': 53,
#  'Missed Recycling: District 04': 111,
#  'Missed Recycling: District 05': 41,
#  'Missed Recycling: District 06': 125,
#  'Missed Recycling: District 07': 57,
#  'Missed Recycling: District 08': 85,
#  'Missed Recycling: District 09': 31,
#  'Missed Recycling: District 10A': 33,
#  'Missed Recycling: District 10B': 35,
#  'Missed Recycling: District 1A': 37,
#  'Missed Recycling: District 1B': 25,
#  'Missed Recycling: District 1C': 68,
#  'Missed Recycling: No Location': 2,
#  'Missed Trash  D10  Roxbury': 1,
#  'Missed Trash  Dorchester': 1,
#  'Missed Trash and Recycling: District 04': 1,
#  'Missed Trash and Recycling: District 09': 1,
#  'Missed Trash/Recycling/Yard Waste/Bulk Item': 61,
#  'Missed Trash: District': 12,
#  'Missed Trash: District 02': 319,
#  'Missed Trash: District 03': 371,
#  'Missed Trash: District 04': 235,
#  'Missed Trash: District 05': 216,
#  'Missed Trash: District 06': 151,
#  'Missed Trash: District 06 [MONDAY]': 1,
#  'Missed Trash: District 07': 366,
#  'Missed Trash: District 08': 204,
#  'Missed Trash: District 09': 127,
#  'Missed Trash: District 10A': 124,
#  'Missed Trash: District 10B': 149,
#  'Missed Trash: District 1A': 72,
#  'Missed Trash: District 1B': 65,
#  'Missed Trash: District 1C': 291,
#  'Missed Trash: No Location': 10,
#  'Missing Sign': 87,
#  'Mission Hill K-8': 1,
#  'Mosquitoes (West Nile)': 1,
#  'Mozart Elementary': 1,
#  'Municipal Parking Lot Complaints': 2,
#  'New Sign  Crosswalk or Pavement Marking': 83,
#  'New Tree Requests': 58,
#  'News Boxes': 38,
#  'No Price on Gas/Wrong Price': 1,
#  'No Utilities - Food Establishment - Water': 1,
#  'No Utilities Residential - Electricity': 7,
#  'No Utilities Residential - Gas': 3,
#  'No Utilities Residential - Water': 46,
#  'No-Tow Complaint Confirmation': 2,
#  'Notification': 12,
#  'OCR Metrolist Inquiries': 3,
#  'OH needed/LAMP #N19311  Ormond St. @ Wellington St./sent': 1,
#  'ONS - Heat - Excessive  Insufficient': 1,
#  'Ohrenberger': 1,
#  'Orchard Gardens K-8': 1,
#  'Other': 11,
#  'Other: Comment': 310,
#  'Other: Complaint': 437,
#  'Other: Compliment': 46,
#  'Outages////LAMP #N15987  90 Pleasant St/sent': 1,
#  'Outages/LAMP #GC141143  337 Marlborough St////printed': 1,
#  'Outages/LAMP #N0158067  7 Everett St/sent': 1,
#  'Outages/LAMP #N0521001  Fellows St. @ Northampton St/sent': 1,
#  'Outages/LAMP #N1879017  Westminster St. @ Huntington/sent': 1,
#  'Outages/LAMP #N2037005  Greenfield Rd. @ Richmere /sent': 1,
#  'Outages/LAMP #N2871002  86 Annunciation St. Opp/sent': 1,
#  'Outages/SLA Suspended - Case SLA Suspended Reason: contractor broke laterals. j burns filed report': 1,
#  'Overcrowding': 5,
#  'Overflowing or Un-kept Dumpster': 30,
#  'PARKS: Comment': 1,
#  'PARKS: Complaint': 8,
#  'PARKS: Compliment': 1,
#  'PRINTED': 357,
#  'PRINTED  Damaged Fixture': 1,
#  'PRINTED  SENT TO MAVERICK': 1,
#  'PRINTED // BEECHAM ST @ ARLINGTON ST': 1,
#  'PRINTED KOED POLE @ #385 NEPONSET AVE': 1,
#  'PRINTED sent to maverick lp #N0044004-1': 1,
#  'PRINTED/': 1,
#  'PRINTED////robert': 3,
#  'PRINTED///Knockdown replacement': 1,
#  'PRINTED//LAMP #N020395  324 Meridian St////robert': 1,
#  'PRINTED/Case SLA Suspended Reason: buried hand hole. no power in pole': 1,
#  'PRINTED/Case SLA Suspended Reason: underground problem': 4,
#  'PRINTED/printed for jim k': 1,
#  'PRINTED/robert': 1,
#  'PRINTED/sent to eng for evaluation': 1,
#  'PWD Graffiti': 432,
#  'Park Improvement Requests': 1,
#  'Park Improvement: Franklin Park': 1,
#  'Park Maintenance:': 1,
#  'Park Maintenance: Polcari Park': 1,
#  'Park Street School': 1,
#  'Parking Enforcement': 458,
#  'Parking Meter Repairs': 8,
#  'Parking on Front/Back Yards (Illegal Parking)': 42,
#  'Parks Dept. Notifications': 1,
#  'Parks General Request': 11,
#  'Pavement Marking Inspection': 7,
#  'Pavement Marking Maintenance': 6,
#  'Pest Infestation - Residential': 19,
#  'Phone Bank Service Inquiry': 5,
#  'Pick up Dead Animal': 102,
#  'Pigeon Infestation': 5,
#  'Planting: Oak Square': 1,
#  'Plumbing': 13,
#  'Police: Full Notifications': 5,
#  'Police: Other': 5,
#  'Police: Pedestrian/Bicyclist struck by MV': 2,
#  'Police: Person(s) Shot/Stabbed': 3,
#  'Poor Conditions of Property': 67,
#  'Poor Ventilation': 2,
#  'Pothole Repair (Internal)': 219,
#  'Power Outage': 18,
#  'Private Parking Lot Complaints': 5,
#  'Protection of Adjoining Property': 15,
#  'Public Works  general request  D 10 Roxbury': 1,
#  'Public Works Contractor Complaint  D6': 1,
#  'Public Works General Request': 100,
#  'PublicWorks: Comment': 89,
#  'PublicWorks: Complaint': 428,
#  'PublicWorks: Complaint  Brighton  D4': 1,
#  'PublicWorks: Complaint  Jamaica Plain  D2': 1,
#  'PublicWorks: Complaint  Missed Trash  D1B': 1,
#  'PublicWorks: Complaint  Missed Trash D7 Dorchester': 1,
#  'PublicWorks: Complaint Missed Trash  D1B': 1,
#  'PublicWorks: Complaint Missed Trash  D6 West Roxbury': 1,
#  'PublicWorks: Complaint Missed Trash D9 East Boston': 1,
#  'PublicWorks: Complaint Missed trash D4 Brighton': 1,
#  'PublicWorks: Compliment': 49,
#  'PublicWorks: Contracor Complaint  Dorchester': 1,
#  'PublicWorks: Contractor Complaint  D1  Beacon Hill': 1,
#  'PublicWorks: Contractor Complaint  D10': 1,
#  'PublicWorks: Contractor Complaint  D3': 1,
#  'PublicWorks: Contractor Complaint  D9': 1,
#  'PublicWorks: Contractor Complaint  Dorchester': 1,
#  'PublicWorks: Contractor Complaint  South Boston': 1,
#  'PublicWorks: Missed Recycling D2 Jamaica Plain': 1,
#  'Rat Bite': 1,
#  'Re-evaluate': 2,
#  'Recycling Cart Return': 9,
#  'Removal of Space Saver': 1,
#  'Renaissance Elementary': 1,
#  'Rental Unit Delivery Conditions': 1,
#  'Repaint Crosswalk - Poor Condition': 11,
#  'Repaint Lane Markings DY - Poor Condition': 1,
#  'Repaint Lane Markings DY and SW - Poor Condition': 1,
#  'Repaint Lane Markings SW - Poor Condition': 1,
#  'Request for Litter Basket Installation': 8,
#  'Request for Pothole Repair': 810,
#  'Request for Recycling Cart': 34,
#  'Request for Snow Plowing': 18619,
#  'Request for Snow Plowing (Emergency Responder)': 464,
#  'Request for Space Savers': 3,
#  'Requests for Street Cleaning': 1083,
#  'Requests for Traffic Signal Studies or Reviews': 77,
#  'Roadway Repair': 8,
#  'Rodent Activity': 53,
#  'Schedule Bulk Item Pickup': 374,
#  'Schedule a Bulk Item Pickup': 746,
#  'School Facility Issues': 180,
#  'Senior Shoveling': 2,
#  'Sewage/Septic Back-Up': 6,
#  'Short Measure - Gas': 3,
#  'Sidewalk Cover / Manhole': 38,
#  'Sidewalk Repair': 26,
#  'Sidewalk Repair (Internal)': 14,
#  'Sidewalk Repair (Make Safe)': 110,
#  'Sidewalk Repair/Concrete/Dist 2': 1,
#  'Sidewalk Repair/Concrete/Dist 3': 1,
#  'Sidewalk Repair/Concrete/Dist 7': 1,
#  'Sidewalk Repair/Concrete/North End': 1,
#  'Sign Repair': 277,
#  'Snow Removal': 7434,
#  'Snow Removal  Trash: District 1C': 1,
#  'Space Savers': 173,
#  'Squalid Living Conditions': 12,
#  'Sticker Request': 186,
#  'Street Cleaning Request': 2,
#  'Street Light Knock Downs': 17,
#  'Street Light Knock Downs   PRINTED!': 2,
#  'Street Light Knock Downs  PRINTED': 1,
#  'Street Light Knock Downs////printed': 3,
#  'Street Light Knock Downs///printed': 1,
#  'Street Light Knock Downs//not a knockdown/open door and wires exposed//printed': 1,
#  'Street Light Outages': 190,
#  'Street Light Outages       ---  PRINTED': 1,
#  'Street Light Outages    SENT TO MAVERICK': 1,
#  'Street Light Outages   // PRINTED //': 1,
#  'Street Light Outages   // SENT TO MAVERICK //': 1,
#  'Street Light Outages   //PRINTED //': 1,
#  'Street Light Outages   SENT TO MAVERICK': 1,
#  'Street Light Outages  (Contractor)': 4,
#  'Street Light Outages  (contractor )': 2,
#  'Street Light Outages  /  SENT TO CANTRACTOR': 1,
#  'Street Light Outages  //  SENT TO MAVERICK //': 1,
#  'Street Light Outages  // PRINTED  //': 1,
#  'Street Light Outages  // PRINTED //': 4,
#  'Street Light Outages  // SENT TO MAVERICK //': 14,
#  'Street Light Outages  // SENT TO MAVERICK ///': 1,
#  'Street Light Outages  // SENT TO MAVERICK//': 1,
#  'Street Light Outages  //PRINTED //': 3,
#  'Street Light Outages  //PRINTED ///': 1,
#  'Street Light Outages  //SENT TO MAVERICK //': 1,
#  'Street Light Outages  //SENT TO MAVERICK//': 1,
#  'Street Light Outages  //SENT TO MAVERICK///': 1,
#  'Street Light Outages  /PRINTED //': 1,
#  'Street Light Outages  LP# N0060013 OR LP # N0060015 SENT TO MAVERICK': 1,
#  'Street Light Outages  LP#N0098008': 1,
#  'Street Light Outages  SENT TO MAVERICK': 2,
#  'Street Light Outages ( Contractor )': 5,
#  'Street Light Outages ( contractoor)': 1,
#  'Street Light Outages ( contractor )': 3,
#  'Street Light Outages (Contractor ranger found)': 1,
#  'Street Light Outages (Contractor)': 3,
#  'Street Light Outages (Internal) Contractor': 1,
#  'Street Light Outages (contractor )': 1,
#  'Street Light Outages (contractor ranger found) Pole #1301/23': 1,
#  'Street Light Outages (contractor)': 5,
#  'Street Light Outages (contractor) Ranger found': 1,
#  'Street Light Outages (contractor) light at Ftwy flood light': 1,
#  'Street Light Outages (contractor) ranger found': 1,
#  'Street Light Outages / PRINTED /': 1,
#  'Street Light Outages // SENT TO MAVERICK //': 3,
#  'Street Light Outages //PRINTED //': 2,
#  'Street Light Outages //SENT TO MAVERICK //': 1,
#  'Street Light Outages //SENT TO MAVERICK////': 1,
#  'Street Light Outages LP # N0098008': 1,
#  'Street Light Outages SENT TO MAVERICK': 1,
#  'Street Light Outages/ PRINTED /': 1,
#  'Street Light Outages// SENT TO MAVERICK  //': 1,
#  'Street Light Outages////pprinted': 1,
#  'Street Light Outages////printed': 17,
#  'Street Light Outages///Install New Lighting': 1,
#  'Street Light Outages///duplicate of #1249271': 1,
#  'Street Light Outages///duplicate of #1249271 & 1249289': 1,
#  'Street Light Outages///duplicate of #1249271 & 1249289& others': 1,
#  'Street Light Outages///duplicate of #1249462': 2,
#  'Street Light Outages///printed': 9,
#  'Street Light Outages///printed///gas': 3,
#  'Street Light Outages///sent to contractor': 14,
#  'Street Light Outages///sent to contractor see photo': 2,
#  'Street Light Outages//Reallocated to Maverick': 1,
#  'Street Light Outages//SENT TO MAVERICK //': 1,
#  'Street Light Outages//duplicate of #1249447': 1,
#  'Street Light Outages//printed': 19,
#  'Street Light Outages//sent to contractor queue': 21,
#  'Street Light Outages//sent to contractor//LP#N026033': 1,
#  'Street Light Outages//sent to maverick': 1,
#  'Street Light Outages//sent to maverick //': 1,
#  'Street Light Outages//this is a duplicate//printed': 1,
#  'Street Light Outages/LAMP #N0017007  62 Seaverns Ave/sent': 1,
#  'Street Light Outages/LAMP #N0027039-1  444 Pond St/sent': 1,
#  'Street Light Outages/LAMP #N0044014-1  78 Carruth St/sent': 1,
#  'Street Light Outages/LAMP #N0074061  543 La Grange St/sent': 1,
#  'Street Light Outages/LAMP #N0076031  269 Temple Stsent': 1,
#  'Street Light Outages/LAMP #N0094007-W  64 Hewlett St/sent': 1,
#  'Street Light Outages/LAMP #N0100004-1  86 Rossmore Rd/nearest asset/sent': 1,
#  'Street Light Outages/LAMP #N010463  120 Southampton St/sent': 1,
#  'Street Light Outages/LAMP #N010721  151 Dorchester St/sent': 1,
#  'Street Light Outages/LAMP #N010724  Dorchester St. @ Gold St./sent': 1,
#  'Street Light Outages/LAMP #N011242  1504 Centre St/sent': 1,
#  'Street Light Outages/LAMP #N011669  120 Brookline Ave/sent': 1,
#  'Street Light Outages/LAMP #N011670  108 Brookline Ave/sent': 1,
#  'Street Light Outages/LAMP #N011841  48 L St/sent': 2,
#  'Street Light Outages/LAMP #N012274  1178 Commonwealth Ave./ nearest asset/sent': 1,
#  'Street Light Outages/LAMP #N012356  1435 Commonwealth Ave/nearest asset/sent': 1,
#  'Street Light Outages/LAMP #N012456  1640 Hyde Park Ave/sent': 1,
#  'Street Light Outages/LAMP #N0133004  50 Everett St/sent': 1,
#  'Street Light Outages/LAMP #N0133008  85 Everett St/sent': 1,
#  'Street Light Outages/LAMP #N0151001-B  Morrow Rd/sent': 1,
#  'Street Light Outages/LAMP #N0151002-B  5 Morrow Rd/sent': 1,
#  'Street Light Outages/LAMP #N017663  858 E. Broadway/sent': 1,
#  'Street Light Outages/LAMP #N018166-S  E. Fifth St. @ M St/sent': 1,
#  'Street Light Outages/LAMP #N019172  26 Cummington St. Opp./nearest asset/sent': 1,
#  'Street Light Outages/LAMP #N023682  31 George St/sent': 1,
#  'Street Light Outages/LAMP #N023926  42 Fuller St./sent': 1,
#  'Street Light Outages/LAMP #N024673  286R P.A. # 443 (Newbury St.)sent': 1,
#  'Street Light Outages/LAMP #N0448002-S  8 Loring St/sent': 1,
#  'Street Light Outages/LAMP #N0509039  353 Cornell St/sent': 1,
#  'Street Light Outages/LAMP #N0556023  215 Wren St/sent': 2,
#  'Street Light Outages/LAMP #N0987101  4965 Washington St. near/sent': 1,
#  'Street Light Outages/LAMP #N1334XXX  115 Northampton St. Opp/sent': 1,
#  'Street Light Outages/LAMP #N1378064  559 Weld St/sent': 1,
#  'Street Light Outages/LAMP #N1599007  45 Lila Rd/sent': 1,
#  'Street Light Outages/LAMP #N1616002  5 Fairview Ave/sent': 1,
#  'Street Light Outages/LAMP #N1789012  68 Ashland St/sent': 1,
#  'Street Light Outages/LAMP #N1829001  Noble Ct./sent': 1,
#  'Street Light Outages/LAMP #N1856017  128 Evans St/sent': 1,
#  'Street Light Outages/LAMP #N1992004  19 Claymont Ter. Opp/sent': 1,
#  'Street Light Outages/LAMP #N2341012  91 Clare Ave/sent': 1,
#  'Street Light Outages/LAMP #N4287XXX  606 E. Fourth St/sent': 1,
#  'Street Light Outages/LAMP #N6028XXX  300 Massachusetts Ave/sent': 1,
#  'Street Light Outages/LAMP #N9462XXX  55 Congress St/sent': 1,
#  'Street Light Outages/LAMP #NFA2616  Washington St. @ Toll Gate Way/sent': 1,
#  'Street Light Outages/no asset for this light': 1,
#  'Street Light Outages/reallocated to DCR': 1,
#  'Street Light Outages/sent': 1,
#  'Street Light Outages/sent to contractor queue': 6,
#  'Street Light Outages/sent to contractors queue': 1,
#  'Street Light Pole Painting': 8,
#  'Street Light box': 1,
#  'Street Lighting Outages//PRINTED': 4,
#  'Street Lighting Pole Knockdown//PRINTED': 1,
#  'Sumner Elementary': 1,
#  'Tobin K-8': 1,
#  'Traffic Signal Repair': 464,
#  'Transportation General Request': 26,
#  'Trash on Vacant Lot': 15,
#  'Tree Emergencies': 41,
#  'Tree In Park: McLean Playground; East Boston': 1,
#  'Tree Maintenance Requests': 267,
#  'Trotter ES': 2,
#  'UP Academy (2450)': 2,
#  'Uncleaniness Site': 1,
#  'Unit Pricing Wrong/Missing': 3,
#  'Unsafe/Dangerous Conditions': 119,
#  'Unsanitary Conditions - Employees': 2,
#  'Unsanitary Conditions - Establishment': 33,
#  'Unsanitary Conditions - Food': 31,
#  'Unsatisfactory Living Conditions': 294,
#  'Unsatisfactory Utilities - Electrical  Plumbing': 25,
#  'Utility Call-In': 81,
#  'Utility Casting Repair': 3,
#  'Walk-In Service Inquiry': 2,
#  'Water in Gas - High Priority': 1,
#  'Watermain Break': 6,
#  'Weather Advisory': 1,
#  'Winship Elementary': 1,
#  'Work Hours-Loud Noise Complaints': 12,
#  'Work w/out Permit': 55,
#  'Working Beyond Hours': 16,
#  'Youthline Idea Collection': 62,
#  'Zoning': 10,
#  'cable install////printed': 1,
#  'contractor complaint': 1,
#  'cycler////printed': 1,
#  'gas outage////printed': 1,
#  'hanging door////printed': 1,
#  'hanging equipment?////printed': 1,
#  'knock down////printed': 2,
#  'knockdown replacement request': 2,
#  'knockdown replacement////printed': 1,
#  'knockdown.////printed': 1,
#  'knockdown////printed': 4,
#  'missing pb cover/printed for jim': 1,
#  'new light installation request/printed for engineering': 1,
#  'on constant////printed': 4,
#  'on constant?/LAMP #N017640  765 E. Broadway/sent': 1,
#  'outage ////printed': 1,
#  'outage on summer street bridge////printed': 1,
#  'outage/// printed for jim k': 1,
#  'outage/////printed': 1,
#  'outage////printed': 102,
#  'outage////printed for jim': 3,
#  'outage////printed for jim k': 13,
#  'outage///printed': 3,
#  'outage///sent': 1,
#  'outage/LAMP #N012642  Seaver St. @ Humboldt Ave/sent': 1,
#  'outage/LAMP #N07852XXX  Milk St. @ Batterymarch St/sent': 1,
#  'outage/printed for jim': 10,
#  'outage/printed for jim k': 1,
#  'outages/////printed': 1,
#  'outages////printed': 9,
#  'picture of outage on moakley bridge': 1,
#  'pole replacement request': 4,
#  'private flood light/reallocated from dept': 1,
#  'sneaker removal/////printed': 1,
#  'stray voltage////printed': 1,
#  'street light box': 1,
#  'street light out ( Contractor )': 1,
#  'street light pole': 1,
#  'traffic signal request': 1,
#  'upgrade request printed for j burns': 1}

# %% [markdown]
# During this process, you may encounter many strange things, that look like outliers. For example, you may notice that there are many values for `CASE_TITLE` which only occur once. One such example is the category
# ```
# "missing pb cover/printed for jim"
# ```
# I really wonder what this means! Try retrieving and printing the whole row **(5 pts)**

# %%
# Print the row tht has CASE_TITLE "missing pb cover/printed for jim"

# There are 2 approaches as follow

# # Using row iteration
# for idx, row in boston.iterrows():
#     if row.CASE_TITLE == "missing pb cover/printed for jim":
#         print boston.iloc[idx,:]
# # Using filter for another approach
# title_in_row = boston[boston.CASE_TITLE == "missing pb cover/printed for jim"]
# print title_in_row

# Using filter
weird_cases = boston[boston.CASE_TITLE == "missing pb cover/printed for jim"]
print weird_cases
# Out:
#      CASE_ENQUIRY_ID             OPEN_DT           TARGET_DT CLOSED_DT  \
# 585     101001241573 2015-01-02 23:18:08 2015-02-16 23:18:08       NaT
#
#     OnTime_Status CASE_STATUS CLOSURE_REASON  \
# 585        ONTIME        Open            NaN
#
#                            CASE_TITLE                  SUBJECT         REASON  \
# 585  missing pb cover/printed for jim  Public Works Department  Street Lights
#
#             ...         precinct land_usage  \
# 585         ...              807        NaN
#
#                                 LOCATION_STREET_NAME LOCATION_ZIPCODE  \
# 585  INTERSECTION Blue Hill Ave & Mount Pleasant Ave              NaN
#
#     Property_Type Property_ID  LATITUDE LONGITUDE            Source  \
# 585  Intersection        1606   42.3253   -71.075  Constituent Call
#
#       Geocoded_Location
# 585  (42.3253, -71.075)
#
# [1 rows x 33 columns]

# %% [markdown]
# There's another category which seems interesting, `Heat - Excessive Insufficient`. Write code that prints the first 10 rows of the dataset that have `CASE_TITLE` which starts with "Heat" and see if you can understand what this stands for **(15 pts)**

# %%
for idx, row in boston.iterrows():
    if str(row.CASE_TITLE).startswith('Heat'):
        print row
#         print boston.iloc[idx,:]
# Out:
# CASE_ENQUIRY_ID                                             101001240754
# OPEN_DT                                              2015-01-01 07:27:13
# TARGET_DT                                            2015-01-31 07:27:13
# CLOSED_DT                                                            NaN
# OnTime_Status                                                    OVERDUE
# CASE_STATUS                                                         Open
# CLOSURE_REASON                                                       NaN
# CASE_TITLE                                Heat - Excessive  Insufficient
# SUBJECT                                            Inspectional Services
# REASON                                                           Housing
# TYPE                                      Heat - Excessive  Insufficient
# QUEUE                                             ISD_Housing (INTERNAL)
# Department                                                           ISD
# SubmittedPhoto                                                       NaN
# ClosedPhoto                                                          NaN
# Location                          1744 Washington St  Roxbury  MA  02118
# fire_district                                                          4
# pwd_district                                                          1C
# city_council_district                                                  2
# police_district                                                       D4
# neighborhood                                                   South End
# neighborhood_services_district                                         6
# ward                                                                  08
# precinct                                                             802
# land_usage                                                           NaN
# LOCATION_STREET_NAME                                  1744 Washington St
# LOCATION_ZIPCODE                                                    2118
# Property_Type                                                    Address
# Property_ID                                                       351061
# LATITUDE                                                         42.3594
# LONGITUDE                                                       -71.0587
# Source                                                  Constituent Call
# Geocoded_Location                                    (42.3594, -71.0587)
# Name: 11, dtype: object
# CASE_ENQUIRY_ID                                       101001240762
# OPEN_DT                                        2015-01-01 08:53:51
# TARGET_DT                                      2015-01-31 08:53:51
# CLOSED_DT                                                      NaN
# OnTime_Status                                              OVERDUE
# CASE_STATUS                                                   Open
# CLOSURE_REASON                                                 NaN
# CASE_TITLE                          Heat - Excessive  Insufficient
# SUBJECT                                      Inspectional Services
# REASON                                                     Housing
# TYPE                                Heat - Excessive  Insufficient
# QUEUE                                       ISD_Housing (INTERNAL)
# Department                                                     ISD
# SubmittedPhoto                                                 NaN
# ClosedPhoto                                                    NaN
# Location                          77 Camden St  Roxbury  MA  02118
# fire_district                                                    7
# pwd_district                                                   10B
# city_council_district                                            7
# police_district                                                 D4
# neighborhood                                               Roxbury
# neighborhood_services_district                                  13
# ward                                                        Ward 9
# precinct                                                       903
# land_usage                                                      EA
# LOCATION_STREET_NAME                                  77 Camden St
# LOCATION_ZIPCODE                                              2118
# Property_Type                                              Address
# Property_ID                                                 201313
# LATITUDE                                                   42.3375
# LONGITUDE                                                 -71.0804
# Source                                            Constituent Call
# Geocoded_Location                              (42.3375, -71.0804)
# Name: 17, dtype: object
# CASE_ENQUIRY_ID                                          101001240786
# OPEN_DT                                           2015-01-01 10:59:01
# TARGET_DT                                         2015-01-31 10:59:01
# CLOSED_DT                                         2015-01-07 08:49:25
# OnTime_Status                                                  ONTIME
# CASE_STATUS                                                    Closed
# CLOSURE_REASON                                          Case Closed :
# CASE_TITLE                             Heat - Excessive  Insufficient
# SUBJECT                                         Inspectional Services
# REASON                                                        Housing
# TYPE                                   Heat - Excessive  Insufficient
# QUEUE                                          ISD_Housing (INTERNAL)
# Department                                                        ISD
# SubmittedPhoto                                                    NaN
# ClosedPhoto                                                       NaN
# Location                          282 Columbus Ave  Boston  MA  02116
# fire_district                                                       4
# pwd_district                                                       1C
# city_council_district                                               2
# police_district                                                    D4
# neighborhood                                                South End
# neighborhood_services_district                                      6
# ward                                                           Ward 4
# precinct                                                          401
# land_usage                                                         RC
# LOCATION_STREET_NAME                                 282 Columbus Ave
# LOCATION_ZIPCODE                                                 2116
# Property_Type                                                 Address
# Property_ID                                                    211739
# LATITUDE                                                      42.3469
# LONGITUDE                                                    -71.0736
# Source                                               Constituent Call
# Geocoded_Location                                 (42.3469, -71.0736)
# Name: 34, dtype: object
# CASE_ENQUIRY_ID                                               101001240809
# OPEN_DT                                                2015-01-01 12:37:13
# TARGET_DT                                              2015-01-31 12:37:13
# CLOSED_DT                                                              NaN
# OnTime_Status                                                      OVERDUE
# CASE_STATUS                                                           Open
# CLOSURE_REASON                                                         NaN
# CASE_TITLE                                  Heat - Excessive  Insufficient
# SUBJECT                                              Inspectional Services
# REASON                                                             Housing
# TYPE                                        Heat - Excessive  Insufficient
# QUEUE                                               ISD_Housing (INTERNAL)
# Department                                                             ISD
# SubmittedPhoto                                                         NaN
# ClosedPhoto                                                            NaN
# Location                          522 Blue Hill Ave  Dorchester  MA  02121
# fire_district                                                            7
# pwd_district                                                            03
# city_council_district                                                    4
# police_district                                                         B2
# neighborhood                                                       Roxbury
# neighborhood_services_district                                          13
# ward                                                               Ward 14
# precinct                                                              1403
# land_usage                                                               A
# LOCATION_STREET_NAME                                     522 Blue Hill Ave
# LOCATION_ZIPCODE                                                      2121
# Property_Type                                                      Address
# Property_ID                                                         190031
# LATITUDE                                                           42.3064
# LONGITUDE                                                         -71.0841
# Source                                                    Constituent Call
# Geocoded_Location                                      (42.3064, -71.0841)
# Name: 50, dtype: object
# CASE_ENQUIRY_ID                                                        101001240837
# OPEN_DT                                                         2015-01-01 14:24:55
# TARGET_DT                                                       2015-01-31 14:24:55
# CLOSED_DT                                                       2015-01-01 14:32:32
# OnTime_Status                                                                ONTIME
# CASE_STATUS                                                                  Closed
# CLOSURE_REASON                    Case Closed Case Invalid landlord called while...
# CASE_TITLE                                           Heat - Excessive  Insufficient
# SUBJECT                                                       Inspectional Services
# REASON                                                                      Housing
# TYPE                                                 Heat - Excessive  Insufficient
# QUEUE                                                        ISD_Housing (INTERNAL)
# Department                                                                      ISD
# SubmittedPhoto                                                                  NaN
# ClosedPhoto                                                                     NaN
# Location                           5070-5072 Washington St  West Roxbury  MA  02132
# fire_district                                                                    12
# pwd_district                                                                     06
# city_council_district                                                             6
# police_district                                                                  E5
# neighborhood                                                           West Roxbury
# neighborhood_services_district                                                   10
# ward                                                                        Ward 20
# precinct                                                                       2003
# land_usage                                                                       R2
# LOCATION_STREET_NAME                                        5070-5072 Washington St
# LOCATION_ZIPCODE                                                               2132
# Property_Type                                                               Address
# Property_ID                                                                  145574
# LATITUDE                                                                    42.2646
# LONGITUDE                                                                  -71.1531
# Source                                                             Constituent Call
# Geocoded_Location                                               (42.2646, -71.1531)
# Name: 74, dtype: object
# CASE_ENQUIRY_ID                                          101001240838
# OPEN_DT                                           2015-01-01 14:25:24
# TARGET_DT                                         2015-01-31 14:25:23
# CLOSED_DT                                                         NaN
# OnTime_Status                                                 OVERDUE
# CASE_STATUS                                                      Open
# CLOSURE_REASON                                                    NaN
# CASE_TITLE                             Heat - Excessive  Insufficient
# SUBJECT                                         Inspectional Services
# REASON                                                        Housing
# TYPE                                   Heat - Excessive  Insufficient
# QUEUE                                          ISD_Housing (INTERNAL)
# Department                                                        ISD
# SubmittedPhoto                                                    NaN
# ClosedPhoto                                                       NaN
# Location                          282 Columbus Ave  Boston  MA  02116
# fire_district                                                       4
# pwd_district                                                       1C
# city_council_district                                               2
# police_district                                                    D4
# neighborhood                                                South End
# neighborhood_services_district                                      6
# ward                                                           Ward 4
# precinct                                                          401
# land_usage                                                         RC
# LOCATION_STREET_NAME                                 282 Columbus Ave
# LOCATION_ZIPCODE                                                 2116
# Property_Type                                                 Address
# Property_ID                                                    211724
# LATITUDE                                                      42.3469
# LONGITUDE                                                    -71.0736
# Source                                               Constituent Call
# Geocoded_Location                                 (42.3469, -71.0736)
# Name: 75, dtype: object
# CASE_ENQUIRY_ID                                        101001240842
# OPEN_DT                                         2015-01-01 14:44:54
# TARGET_DT                                       2015-01-31 14:44:54
# CLOSED_DT                                                       NaN
# OnTime_Status                                               OVERDUE
# CASE_STATUS                                                    Open
# CLOSURE_REASON                                                  NaN
# CASE_TITLE                           Heat - Excessive  Insufficient
# SUBJECT                                       Inspectional Services
# REASON                                                      Housing
# TYPE                                 Heat - Excessive  Insufficient
# QUEUE                                        ISD_Housing (INTERNAL)
# Department                                                      ISD
# SubmittedPhoto                                                  NaN
# ClosedPhoto                                                     NaN
# Location                          72 Gardner St  Allston  MA  02134
# fire_district                                                    11
# pwd_district                                                     04
# city_council_district                                             9
# police_district                                                 D14
# neighborhood                                     Allston / Brighton
# neighborhood_services_district                                   15
# ward                                                        Ward 21
# precinct                                                       2104
# land_usage                                                        A
# LOCATION_STREET_NAME                                  72 Gardner St
# LOCATION_ZIPCODE                                               2134
# Property_Type                                               Address
# Property_ID                                                  239609
# LATITUDE                                                     42.354
# LONGITUDE                                                  -71.1273
# Source                                                 Self Service
# Geocoded_Location                                (42.354, -71.1273)
# Name: 78, dtype: object
# CASE_ENQUIRY_ID                                            101001240863
# OPEN_DT                                             2015-01-01 17:13:28
# TARGET_DT                                           2015-01-31 17:13:28
# CLOSED_DT                                                           NaN
# OnTime_Status                                                   OVERDUE
# CASE_STATUS                                                        Open
# CLOSURE_REASON                                                      NaN
# CASE_TITLE                               Heat - Excessive  Insufficient
# SUBJECT                                           Inspectional Services
# REASON                                                          Housing
# TYPE                                     Heat - Excessive  Insufficient
# QUEUE                                            ISD_Housing (INTERNAL)
# Department                                                          ISD
# SubmittedPhoto                                                      NaN
# ClosedPhoto                                                         NaN
# Location                          11-25 E Newton St  Roxbury  MA  02118
# fire_district                                                         4
# pwd_district                                                         1C
# city_council_district                                                 2
# police_district                                                      D4
# neighborhood                                                  South End
# neighborhood_services_district                                        6
# ward                                                             Ward 8
# precinct                                                            802
# land_usage                                                           CM
# LOCATION_STREET_NAME                                  11-25 E Newton St
# LOCATION_ZIPCODE                                                   2118
# Property_Type                                                   Address
# Property_ID                                                      102338
# LATITUDE                                                        42.3382
# LONGITUDE                                                      -71.0731
# Source                                                 Constituent Call
# Geocoded_Location                                   (42.3382, -71.0731)
# Name: 94, dtype: object
# CASE_ENQUIRY_ID                                               101001240882
# OPEN_DT                                                2015-01-01 19:25:55
# TARGET_DT                                              2015-01-31 19:25:55
# CLOSED_DT                                                              NaN
# OnTime_Status                                                      OVERDUE
# CASE_STATUS                                                           Open
# CLOSURE_REASON                                                         NaN
# CASE_TITLE                                  Heat - Excessive  Insufficient
# SUBJECT                                              Inspectional Services
# REASON                                                             Housing
# TYPE                                        Heat - Excessive  Insufficient
# QUEUE                                               ISD_Housing (INTERNAL)
# Department                                                             ISD
# SubmittedPhoto                                                         NaN
# ClosedPhoto                                                            NaN
# Location                          950 Canterbury St  Roslindale  MA  02131
# fire_district                                                           12
# pwd_district                                                            08
# city_council_district                                                    5
# police_district                                                        E18
# neighborhood                                                    Roslindale
# neighborhood_services_district                                          10
# ward                                                               Ward 18
# precinct                                                              1808
# land_usage                                                               A
# LOCATION_STREET_NAME                                     950 Canterbury St
# LOCATION_ZIPCODE                                                      2131
# Property_Type                                                      Address
# Property_ID                                                         201733
# LATITUDE                                                           42.2785
# LONGITUDE                                                         -71.1172
# Source                                                    Constituent Call
# Geocoded_Location                                      (42.2785, -71.1172)
# Name: 107, dtype: object
# CASE_ENQUIRY_ID                                         101001240896
# OPEN_DT                                          2015-01-01 22:11:51
# TARGET_DT                                        2015-01-31 22:11:50
# CLOSED_DT                                                        NaN
# OnTime_Status                                                OVERDUE
# CASE_STATUS                                                     Open
# CLOSURE_REASON                                                   NaN
# CASE_TITLE                            Heat - Excessive  Insufficient
# SUBJECT                                        Inspectional Services
# REASON                                                       Housing
# TYPE                                  Heat - Excessive  Insufficient
# QUEUE                                         ISD_Housing (INTERNAL)
# Department                                                       ISD
# SubmittedPhoto                                                   NaN
# ClosedPhoto                                                      NaN
# Location                          31 Wales St  Dorchester  MA  02124
# fire_district                                                      7
# pwd_district                                                      03
# city_council_district                                              4
# police_district                                                   B3
# neighborhood                                        Greater Mattapan
# neighborhood_services_district                                     8
# ward                                                         Ward 14
# precinct                                                        1407
# land_usage                                                         A
# LOCATION_STREET_NAME                                     31 Wales St
# LOCATION_ZIPCODE                                                2124
# Property_Type                                                Address
# Property_ID                                                   326017
# LATITUDE                                                     42.2969
# LONGITUDE                                                    -71.085
# Source                                              Constituent Call
# Geocoded_Location                                 (42.2969, -71.085)
# Name: 117, dtype: object
# CASE_ENQUIRY_ID                                         101001240900
# OPEN_DT                                          2015-01-01 23:01:33
# TARGET_DT                                        2015-01-31 23:01:33
# CLOSED_DT                                                        NaN
# OnTime_Status                                                OVERDUE
# CASE_STATUS                                                     Open
# CLOSURE_REASON                                                   NaN
# CASE_TITLE                            Heat - Excessive  Insufficient
# SUBJECT                                        Inspectional Services
# REASON                                                       Housing
# TYPE                                  Heat - Excessive  Insufficient
# QUEUE                                         ISD_Housing (INTERNAL)
# Department                                                       ISD
# SubmittedPhoto                                                   NaN
# ClosedPhoto                                                      NaN
# Location                          6 Nelson St  Dorchester  MA  02124
# fire_district                                                      8
# pwd_district                                                      07
# city_council_district                                              4
# police_district                                                   B3
# neighborhood                                              Dorchester
# neighborhood_services_district                                     9
# ward                                                         Ward 17
# precinct                                                        1710
# land_usage                                                        R3
# LOCATION_STREET_NAME                                     6 Nelson St
# LOCATION_ZIPCODE                                                2124
# Property_Type                                                Address
# Property_ID                                                   281215
# LATITUDE                                                     42.2832
# LONGITUDE                                                   -71.0829
# Source                                              Constituent Call
# Geocoded_Location                                (42.2832, -71.0829)
# Name: 120, dtype: object
# CASE_ENQUIRY_ID                                           101001240968
# OPEN_DT                                            2015-01-02 08:27:51
# TARGET_DT                                          2015-02-01 08:27:51
# CLOSED_DT                                                          NaN
# OnTime_Status                                                  OVERDUE
# CASE_STATUS                                                       Open
# CLOSURE_REASON                                                     NaN
# CASE_TITLE                              Heat - Excessive  Insufficient
# SUBJECT                                          Inspectional Services
# REASON                                                         Housing
# TYPE                                    Heat - Excessive  Insufficient
# QUEUE                                           ISD_Housing (INTERNAL)
# Department                                                         ISD
# SubmittedPhoto                                                     NaN
# ClosedPhoto                                                        NaN
# Location                          21 Sargent St  Dorchester  MA  02125
# fire_district                                                        7
# pwd_district                                                        03
# city_council_district                                                7
# police_district                                                     B2
# neighborhood                                                   Roxbury
# neighborhood_services_district                                      13
# ward                                                           Ward 13
# precinct                                                          1304
# land_usage                                                          R3
# LOCATION_STREET_NAME                                     21 Sargent St
# LOCATION_ZIPCODE                                                  2125
# Property_Type                                                  Address
# Property_ID                                                     306492
# LATITUDE                                                       42.3161
# LONGITUDE                                                     -71.0741
# Source                                                Constituent Call
# Geocoded_Location                                  (42.3161, -71.0741)
# Name: 165, dtype: object
# CASE_ENQUIRY_ID                                        101001241156
# OPEN_DT                                         2015-01-02 10:42:51
# TARGET_DT                                       2015-02-01 10:42:50
# CLOSED_DT                                                       NaN
# OnTime_Status                                               OVERDUE
# CASE_STATUS                                                    Open
# CLOSURE_REASON                                                  NaN
# CASE_TITLE                           Heat - Excessive  Insufficient
# SUBJECT                                       Inspectional Services
# REASON                                                      Housing
# TYPE                                 Heat - Excessive  Insufficient
# QUEUE                                        ISD_Housing (INTERNAL)
# Department                                                      ISD
# SubmittedPhoto                                                  NaN
# ClosedPhoto                                                     NaN
# Location                          153 River St  Mattapan  MA  02126
# fire_district                                                     8
# pwd_district                                                     07
# city_council_district                                             4
# police_district                                                  B3
# neighborhood                                       Greater Mattapan
# neighborhood_services_district                                    9
# ward                                                        Ward 18
# precinct                                                       1801
# land_usage                                                       R3
# LOCATION_STREET_NAME                                   153 River St
# LOCATION_ZIPCODE                                               2126
# Property_Type                                               Address
# Property_ID                                                  159213
# LATITUDE                                                    42.2718
# LONGITUDE                                                  -71.0775
# Source                                             Constituent Call
# Geocoded_Location                               (42.2718, -71.0775)
# Name: 306, dtype: object
# CASE_ENQUIRY_ID                                           101001241160
# OPEN_DT                                            2015-01-02 10:44:23
# TARGET_DT                                          2015-02-01 10:44:23
# CLOSED_DT                                          2015-01-21 10:57:01
# OnTime_Status                                                   ONTIME
# CASE_STATUS                                                     Closed
# CLOSURE_REASON                                           Case Closed :
# CASE_TITLE                              Heat - Excessive  Insufficient
# SUBJECT                                          Inspectional Services
# REASON                                                         Housing
# TYPE                                    Heat - Excessive  Insufficient
# QUEUE                                           ISD_Housing (INTERNAL)
# Department                                                         ISD
# SubmittedPhoto                                                     NaN
# ClosedPhoto                                                        NaN
# Location                          31 Boulevard Ter  Allston  MA  02134
# fire_district                                                       11
# pwd_district                                                        04
# city_council_district                                                9
# police_district                                                    D14
# neighborhood                                        Allston / Brighton
# neighborhood_services_district                                      15
# ward                                                           Ward 21
# precinct                                                          2109
# land_usage                                                          R2
# LOCATION_STREET_NAME                                  31 Boulevard Ter
# LOCATION_ZIPCODE                                                  2134
# Property_Type                                                  Address
# Property_ID                                                     191435
# LATITUDE                                                       42.3474
# LONGITUDE                                                     -71.1396
# Source                                                Constituent Call
# Geocoded_Location                                  (42.3474, -71.1396)
# Name: 308, dtype: object
# CASE_ENQUIRY_ID                                            101001241162
# OPEN_DT                                             2015-01-02 10:47:39
# TARGET_DT                                           2015-02-01 10:47:39
# CLOSED_DT                                                           NaN
# OnTime_Status                                                   OVERDUE
# CASE_STATUS                                                        Open
# CLOSURE_REASON                                                      NaN
# CASE_TITLE                               Heat - Excessive  Insufficient
# SUBJECT                                           Inspectional Services
# REASON                                                          Housing
# TYPE                                     Heat - Excessive  Insufficient
# QUEUE                                            ISD_Housing (INTERNAL)
# Department                                                          ISD
# SubmittedPhoto                                                      NaN
# ClosedPhoto                                                         NaN
# Location                          356 Ashmont St  Dorchester  MA  02124
# fire_district                                                         8
# pwd_district                                                         07
# city_council_district                                                 3
# police_district                                                     C11
# neighborhood                                                 Dorchester
# neighborhood_services_district                                        7
# ward                                                            Ward 16
# precinct                                                           1606
# land_usage                                                            E
# LOCATION_STREET_NAME                                     356 Ashmont St
# LOCATION_ZIPCODE                                                   2124
# Property_Type                                                   Address
# Property_ID                                                      174171
# LATITUDE                                                        42.2882
# LONGITUDE                                                      -71.0577
# Source                                                 Constituent Call
# Geocoded_Location                                   (42.2882, -71.0577)
# Name: 310, dtype: object
# CASE_ENQUIRY_ID                                           101001241201
# OPEN_DT                                            2015-01-02 11:09:36
# TARGET_DT                                          2015-02-01 11:09:36
# CLOSED_DT                                                          NaN
# OnTime_Status                                                  OVERDUE
# CASE_STATUS                                                       Open
# CLOSURE_REASON                                                     NaN
# CASE_TITLE                              Heat - Excessive  Insufficient
# SUBJECT                                          Inspectional Services
# REASON                                                         Housing
# TYPE                                    Heat - Excessive  Insufficient
# QUEUE                                           ISD_Housing (INTERNAL)
# Department                                                         ISD
# SubmittedPhoto                                                     NaN
# ClosedPhoto                                                        NaN
# Location                          9 Carmel St  Mission Hill  MA  02120
# fire_district                                                        9
# pwd_district                                                       10A
# city_council_district                                                8
# police_district                                                     B2
# neighborhood                                              Mission Hill
# neighborhood_services_district                                      14
# ward                                                           Ward 10
# precinct                                                          1002
# land_usage                                                          R3
# LOCATION_STREET_NAME                                       9 Carmel St
# LOCATION_ZIPCODE                                                  2120
# Property_Type                                                  Address
# Property_ID                                                     202047
# LATITUDE                                                       42.3322
# LONGITUDE                                                     -71.1004
# Source                                                Constituent Call
# Geocoded_Location                                  (42.3322, -71.1004)
# Name: 339, dtype: object
# CASE_ENQUIRY_ID                                       101001241387
# OPEN_DT                                        2015-01-02 14:15:28
# TARGET_DT                                      2015-02-01 14:15:28
# CLOSED_DT                                                      NaN
# OnTime_Status                                              OVERDUE
# CASE_STATUS                                                   Open
# CLOSURE_REASON                                                 NaN
# CASE_TITLE                          Heat - Excessive  Insufficient
# SUBJECT                                      Inspectional Services
# REASON                                                     Housing
# TYPE                                Heat - Excessive  Insufficient
# QUEUE                                       ISD_Housing (INTERNAL)
# Department                                                     ISD
# SubmittedPhoto                                                 NaN
# ClosedPhoto                                                    NaN
# Location                          8 Wardman Rd  Roxbury  MA  02119
# fire_district                                                    9
# pwd_district                                                   10B
# city_council_district                                            7
# police_district                                                E13
# neighborhood                                               Roxbury
# neighborhood_services_district                                  13
# ward                                                       Ward 11
# precinct                                                      1103
# land_usage                                                      R2
# LOCATION_STREET_NAME                                  8 Wardman Rd
# LOCATION_ZIPCODE                                              2119
# Property_Type                                              Address
# Property_ID                                                 328210
# LATITUDE                                                   42.3153
# LONGITUDE                                                 -71.0946
# Source                                            Constituent Call
# Geocoded_Location                              (42.3153, -71.0946)
# Name: 467, dtype: object
# CASE_ENQUIRY_ID                                                 101001241494
# OPEN_DT                                                  2015-01-02 15:57:56
# TARGET_DT                                                2015-02-01 15:57:56
# CLOSED_DT                                                                NaN
# OnTime_Status                                                        OVERDUE
# CASE_STATUS                                                             Open
# CLOSURE_REASON                                                           NaN
# CASE_TITLE                                    Heat - Excessive  Insufficient
# SUBJECT                                                Inspectional Services
# REASON                                                               Housing
# TYPE                                          Heat - Excessive  Insufficient
# QUEUE                                                 ISD_Housing (INTERNAL)
# Department                                                               ISD
# SubmittedPhoto                                                           NaN
# ClosedPhoto                                                              NaN
# Location                          1526 Commonwealth Ave  Brighton  MA  02135
# fire_district                                                             11
# pwd_district                                                              04
# city_council_district                                                      9
# police_district                                                          D14
# neighborhood                                              Allston / Brighton
# neighborhood_services_district                                            15
# ward                                                                 Ward 21
# precinct                                                                2110
# land_usage                                                                R2
# LOCATION_STREET_NAME                                   1526 Commonwealth Ave
# LOCATION_ZIPCODE                                                        2135
# Property_Type                                                        Address
# Property_ID                                                           215141
# LATITUDE                                                             42.3453
# LONGITUDE                                                           -71.1413
# Source                                                          Self Service
# Geocoded_Location                                        (42.3453, -71.1413)
# Name: 528, dtype: object
# CASE_ENQUIRY_ID                                               101001241589
# OPEN_DT                                                2015-01-03 07:23:16
# TARGET_DT                                              2015-02-02 07:23:16
# CLOSED_DT                                              2015-01-21 09:53:43
# OnTime_Status                                                       ONTIME
# CASE_STATUS                                                         Closed
# CLOSURE_REASON                                               Case Closed :
# CASE_TITLE                                  Heat - Excessive  Insufficient
# SUBJECT                                              Inspectional Services
# REASON                                                             Housing
# TYPE                                        Heat - Excessive  Insufficient
# QUEUE                                               ISD_Housing (INTERNAL)
# Department                                                             ISD
# SubmittedPhoto                                                         NaN
# ClosedPhoto                                                            NaN
# Location                          6 Mount Pleasant Ter  Roxbury  MA  02119
# fire_district                                                            7
# pwd_district                                                           10B
# city_council_district                                                    7
# police_district                                                         B2
# neighborhood                                                       Roxbury
# neighborhood_services_district                                          13
# ward                                                                Ward 8
# precinct                                                               804
# land_usage                                                              R3
# LOCATION_STREET_NAME                                  6 Mount Pleasant Ter
# LOCATION_ZIPCODE                                                      2119
# Property_Type                                                      Address
# Property_ID                                                          98451
# LATITUDE                                                           42.3264
# LONGITUDE                                                           -71.08
# Source                                                    Constituent Call
# Geocoded_Location                                        (42.3264, -71.08)
# Name: 596, dtype: object
# CASE_ENQUIRY_ID                                                     101001241623
# OPEN_DT                                                      2015-01-03 10:23:15
# TARGET_DT                                                    2015-02-02 10:23:15
# CLOSED_DT                                                    2015-01-21 09:57:57
# OnTime_Status                                                             ONTIME
# CASE_STATUS                                                               Closed
# CLOSURE_REASON                    Case Closed NOVIO: No Violation Found/No Cause
# CASE_TITLE                                        Heat - Excessive  Insufficient
# SUBJECT                                                    Inspectional Services
# REASON                                                                   Housing
# TYPE                                              Heat - Excessive  Insufficient
# QUEUE                                                     ISD_Housing (INTERNAL)
# Department                                                                   ISD
# SubmittedPhoto                                                               NaN
# ClosedPhoto                                                                  NaN
# Location                                   90 Columbia Rd  Dorchester  MA  02121
# fire_district                                                                  7
# pwd_district                                                                  03
# city_council_district                                                          4
# police_district                                                               B2
# neighborhood                                                             Roxbury
# neighborhood_services_district                                                13
# ward                                                                     Ward 14
# precinct                                                                    1403
# land_usage                                                                     A
# LOCATION_STREET_NAME                                              90 Columbia Rd
# LOCATION_ZIPCODE                                                            2121
# Property_Type                                                            Address
# Property_ID                                                                35449
# LATITUDE                                                                 42.3051
# LONGITUDE                                                               -71.0817
# ...
# Department                                                             ISD
# SubmittedPhoto                                                         NaN
# ClosedPhoto                                                            NaN
# Location                          15 Hollingsworth St  Mattapan  MA  02126
# fire_district                                                            8
# pwd_district                                                            08
# city_council_district                                                    4
# police_district                                                        E18
# neighborhood                                              Greater Mattapan
# neighborhood_services_district                                           9
# ward                                                               Ward 18
# precinct                                                              1804
# land_usage                                                              R3
# LOCATION_STREET_NAME                                   15 Hollingsworth St
# LOCATION_ZIPCODE                                                      2126
# Property_Type                                                      Address
# Property_ID                                                         252657
# LATITUDE                                                           42.2693
# LONGITUDE                                                         -71.0981
# Source                                                    Constituent Call
# Geocoded_Location                                      (42.2693, -71.0981)
# Name: 45945, dtype: object
# CASE_ENQUIRY_ID                                                   101001294564
# OPEN_DT                                                    2015-02-14 08:02:18
# TARGET_DT                                                  2015-03-16 08:02:17
# CLOSED_DT                                                                  NaN
# OnTime_Status                                                           ONTIME
# CASE_STATUS                                                               Open
# CLOSURE_REASON                                                             NaN
# CASE_TITLE                                      Heat - Excessive  Insufficient
# SUBJECT                                                  Inspectional Services
# REASON                                                                 Housing
# TYPE                                            Heat - Excessive  Insufficient
# QUEUE                                                   ISD_Housing (INTERNAL)
# Department                                                                 ISD
# SubmittedPhoto                                                             NaN
# ClosedPhoto                                                                NaN
# Location                                  94 Queensberry St  Boston  MA  02215
# fire_district                                                                4
# pwd_district                                                               10A
# city_council_district                                                        8
# police_district                                                             D4
# neighborhood                      Fenway / Kenmore / Audubon Circle / Longwood
# neighborhood_services_district                                              14
# ward                                                                   Ward 21
# precinct                                                                  2101
# land_usage                                                                   A
# LOCATION_STREET_NAME                                         94 Queensberry St
# LOCATION_ZIPCODE                                                          2215
# Property_Type                                                          Address
# Property_ID                                                             296998
# LATITUDE                                                                42.342
# LONGITUDE                                                             -71.0992
# Source                                                            Self Service
# Geocoded_Location                                           (42.342, -71.0992)
# Name: 45966, dtype: object
# CASE_ENQUIRY_ID                                         101001294911
# OPEN_DT                                          2015-02-14 12:45:11
# TARGET_DT                                        2015-03-16 12:45:10
# CLOSED_DT                                                        NaN
# OnTime_Status                                                 ONTIME
# CASE_STATUS                                                     Open
# CLOSURE_REASON                                                   NaN
# CASE_TITLE                            Heat - Excessive  Insufficient
# SUBJECT                                        Inspectional Services
# REASON                                                       Housing
# TYPE                                  Heat - Excessive  Insufficient
# QUEUE                                         ISD_Housing (INTERNAL)
# Department                                                       ISD
# SubmittedPhoto                                                   NaN
# ClosedPhoto                                                      NaN
# Location                          241 Walnut Ave  Roxbury  MA  02119
# fire_district                                                      9
# pwd_district                                                     10B
# city_council_district                                              7
# police_district                                                   B2
# neighborhood                                                 Roxbury
# neighborhood_services_district                                    13
# ward                                                         Ward 11
# precinct                                                        1103
# land_usage                                                         A
# LOCATION_STREET_NAME                                  241 Walnut Ave
# LOCATION_ZIPCODE                                                2119
# Property_Type                                                Address
# Property_ID                                                   141915
# LATITUDE                                                     42.3186
# LONGITUDE                                                   -71.0913
# Source                                              Constituent Call
# Geocoded_Location                                (42.3186, -71.0913)
# Name: 46272, dtype: object
# CASE_ENQUIRY_ID                                          101001295137
# OPEN_DT                                           2015-02-14 15:25:19
# TARGET_DT                                         2015-03-16 15:25:18
# CLOSED_DT                                         2015-02-14 15:27:30
# OnTime_Status                                                  ONTIME
# CASE_STATUS                                                    Closed
# CLOSURE_REASON                               Case Closed Case Invalid
# CASE_TITLE                             Heat - Excessive  Insufficient
# SUBJECT                                         Inspectional Services
# REASON                                                        Housing
# TYPE                                   Heat - Excessive  Insufficient
# QUEUE                                          ISD_Housing (INTERNAL)
# Department                                                        ISD
# SubmittedPhoto                                                    NaN
# ClosedPhoto                                                       NaN
# Location                          282 Columbus Ave  Boston  MA  02116
# fire_district                                                       4
# pwd_district                                                       1C
# city_council_district                                               2
# police_district                                                    D4
# neighborhood                                                South End
# neighborhood_services_district                                      6
# ward                                                           Ward 4
# precinct                                                          401
# land_usage                                                         RC
# LOCATION_STREET_NAME                                 282 Columbus Ave
# LOCATION_ZIPCODE                                                 2116
# Property_Type                                                 Address
# Property_ID                                                    211739
# LATITUDE                                                      42.3469
# LONGITUDE                                                    -71.0736
# Source                                               Constituent Call
# Geocoded_Location                                 (42.3469, -71.0736)
# Name: 46477, dtype: object
# CASE_ENQUIRY_ID                                          101001295181
# OPEN_DT                                           2015-02-14 16:09:01
# TARGET_DT                                         2015-03-16 16:09:01
# CLOSED_DT                                                         NaN
# OnTime_Status                                                  ONTIME
# CASE_STATUS                                                      Open
# CLOSURE_REASON                                                    NaN
# CASE_TITLE                             Heat - Excessive  Insufficient
# SUBJECT                                         Inspectional Services
# REASON                                                        Housing
# TYPE                                   Heat - Excessive  Insufficient
# QUEUE                                          ISD_Housing (INTERNAL)
# Department                                                        ISD
# SubmittedPhoto                                                    NaN
# ClosedPhoto                                                       NaN
# Location                          45-47 Bayard St  Allston  MA  02134
# fire_district                                                      11
# pwd_district                                                       04
# city_council_district                                               9
# police_district                                                   D14
# neighborhood                                       Allston / Brighton
# neighborhood_services_district                                     15
# ward                                                          Ward 22
# precinct                                                         2201
# land_usage                                                         R2
# LOCATION_STREET_NAME                                  45-47 Bayard St
# LOCATION_ZIPCODE                                                 2134
# Property_Type                                                 Address
# Property_ID                                                      9203
# LATITUDE                                                      42.3603
# LONGITUDE                                                    -71.1317
# Source                                               Constituent Call
# Geocoded_Location                                 (42.3603, -71.1317)
# Name: 46517, dtype: object
# CASE_ENQUIRY_ID                                        101001295270
# OPEN_DT                                         2015-02-14 17:51:55
# TARGET_DT                                       2015-03-16 17:51:55
# CLOSED_DT                                                       NaN
# OnTime_Status                                                ONTIME
# CASE_STATUS                                                    Open
# CLOSURE_REASON                                                  NaN
# CASE_TITLE                           Heat - Excessive  Insufficient
# SUBJECT                                       Inspectional Services
# REASON                                                      Housing
# TYPE                                 Heat - Excessive  Insufficient
# QUEUE                                        ISD_Housing (INTERNAL)
# Department                                                      ISD
# SubmittedPhoto                                                  NaN
# ClosedPhoto                                                     NaN
# Location                          48 Hosmer St  Mattapan  MA  02126
# fire_district                                                     8
# pwd_district                                                     07
# city_council_district                                             4
# police_district                                                  B3
# neighborhood                                       Greater Mattapan
# neighborhood_services_district                                    9
# ward                                                        Ward 14
# precinct                                                       1405
# land_usage                                                       CD
# LOCATION_STREET_NAME                                   48 Hosmer St
# LOCATION_ZIPCODE                                               2126
# Property_Type                                               Address
# Property_ID                                                   75402
# LATITUDE                                                    42.2805
# LONGITUDE                                                  -71.0893
# Source                                             Constituent Call
# Geocoded_Location                               (42.2805, -71.0893)
# Name: 46596, dtype: object
# CASE_ENQUIRY_ID                                              101001295372
# OPEN_DT                                               2015-02-14 22:08:08
# TARGET_DT                                             2015-03-16 22:08:07
# CLOSED_DT                                                             NaN
# OnTime_Status                                                      ONTIME
# CASE_STATUS                                                          Open
# CLOSURE_REASON                                                        NaN
# CASE_TITLE                                 Heat - Excessive  Insufficient
# SUBJECT                                             Inspectional Services
# REASON                                                            Housing
# TYPE                                       Heat - Excessive  Insufficient
# QUEUE                                              ISD_Housing (INTERNAL)
# Department                                                            ISD
# SubmittedPhoto                                                        NaN
# ClosedPhoto                                                           NaN
# Location                          119 Armandine St  Dorchester  MA  02124
# fire_district                                                           8
# pwd_district                                                           07
# city_council_district                                                   4
# police_district                                                        B3
# neighborhood                                                   Dorchester
# neighborhood_services_district                                          9
# ward                                                              Ward 17
# precinct                                                             1708
# land_usage                                                             R3
# LOCATION_STREET_NAME                                     119 Armandine St
# LOCATION_ZIPCODE                                                     2124
# Property_Type                                                     Address
# Property_ID                                                          4942
# LATITUDE                                                           42.284
# LONGITUDE                                                        -71.0762
# Source                                                   Constituent Call
# Geocoded_Location                                      (42.284, -71.0762)
# Name: 46674, dtype: object

# %% [markdown]
# Now, let's plot (preferably with horizontal bars) the counts for all the `CASE_TITLE`s that occur more than 250 times in the dataset. **(5 pts)**

# %%
# Plots the high-occuring categories for cases as a horizontal histogram.
titles_250 = {i:titles[i] for i in titles if titles[i] > 250}
num_appear = [titles_250[i] for i in titles_250]
title_label = [i for i in titles_250]
# print num_appear, title_label
y_pos = [i for i in range(len(num_appear))]
plt.barh(y_pos,num_appear,align='center')
plt.yticks(y_pos, title_label)
# Out:
# ([<matplotlib.axis.YTick at 0x1138c6650>,
#   <matplotlib.axis.YTick at 0x1138c8f50>,
#   <matplotlib.axis.YTick at 0x11396e910>,
#   <matplotlib.axis.YTick at 0x113838290>,
#   <matplotlib.axis.YTick at 0x113838a10>,
#   <matplotlib.axis.YTick at 0x1137c31d0>,
#   <matplotlib.axis.YTick at 0x1137c3950>,
#   <matplotlib.axis.YTick at 0x1137cd110>,
#   <matplotlib.axis.YTick at 0x1137cd890>,
#   <matplotlib.axis.YTick at 0x1137d6050>,
#   <matplotlib.axis.YTick at 0x1137d67d0>,
#   <matplotlib.axis.YTick at 0x1137d6f50>,
#   <matplotlib.axis.YTick at 0x1137df710>,
#   <matplotlib.axis.YTick at 0x1137dfe90>,
#   <matplotlib.axis.YTick at 0x1137e9650>,
#   <matplotlib.axis.YTick at 0x1137e9dd0>,
#   <matplotlib.axis.YTick at 0x1137f2590>,
#   <matplotlib.axis.YTick at 0x1137f2d10>,
#   <matplotlib.axis.YTick at 0x1137fc4d0>,
#   <matplotlib.axis.YTick at 0x1137fcc50>,
#   <matplotlib.axis.YTick at 0x113786410>,
#   <matplotlib.axis.YTick at 0x113786b90>,
#   <matplotlib.axis.YTick at 0x113790350>,
#   <matplotlib.axis.YTick at 0x113790ad0>,
#   <matplotlib.axis.YTick at 0x113799290>,
#   <matplotlib.axis.YTick at 0x113799a10>,
#   <matplotlib.axis.YTick at 0x1137a41d0>],
#  <a list of 27 Text yticklabel objects>)

# %% [markdown]
# As you can see, the most common categories are related to snow. Let us see which neighborhoods were mostly affected by snow problems. This information is saved under the `neighborhood` column. Make a plot (similar to the one above, like a horizontal histogram) that for each neighborhood shows the number of snow-related calls made from there. **(5 pts)**

# %%
snow = {}
for idx, row in boston.iterrows():
    title = row.CASE_TITLE
    neighbor = row.neighborhood
    # search for the keyword 'snow'
    if 'Snow' in str(title):
        if neighbor in snow:
            snow[neighbor] += 1
        if not (neighbor in snow):
            snow[neighbor] = 1
# pprint(snow)
num_appear = [snow[i] for i in snow]
neighbor_label = [i for i in snow]
# print num_appear, title_label
y_pos = [i for i in range(len(num_appear))]
plt.barh(y_pos,num_appear,align='center')
plt.yticks(y_pos, neighbor_label)
# Out:
# ([<matplotlib.axis.YTick at 0x11389aa90>,
#   <matplotlib.axis.YTick at 0x11372aa90>,
#   <matplotlib.axis.YTick at 0x113722f50>,
#   <matplotlib.axis.YTick at 0x113a6fa10>,
#   <matplotlib.axis.YTick at 0x113a631d0>,
#   <matplotlib.axis.YTick at 0x113a63950>,
#   <matplotlib.axis.YTick at 0x113a59110>,
#   <matplotlib.axis.YTick at 0x113a59890>,
#   <matplotlib.axis.YTick at 0x113352050>,
#   <matplotlib.axis.YTick at 0x1133527d0>,
#   <matplotlib.axis.YTick at 0x113352f50>,
#   <matplotlib.axis.YTick at 0x11335b710>,
#   <matplotlib.axis.YTick at 0x11335be90>,
#   <matplotlib.axis.YTick at 0x113365650>,
#   <matplotlib.axis.YTick at 0x113365dd0>,
#   <matplotlib.axis.YTick at 0x11336e590>,
#   <matplotlib.axis.YTick at 0x11336ed10>,
#   <matplotlib.axis.YTick at 0x1133774d0>,
#   <matplotlib.axis.YTick at 0x113377c50>,
#   <matplotlib.axis.YTick at 0x10da1f410>,
#   <matplotlib.axis.YTick at 0x10da1fb90>,
#   <matplotlib.axis.YTick at 0x10da17350>,
#   <matplotlib.axis.YTick at 0x10da17ad0>],
#  <a list of 23 Text yticklabel objects>)

# %% [markdown]
# ## Step 3. Advanced filtering & joins

# %% [markdown]
# By now, you should have noticed that, for each day, there are multiple records in our dataframe. Use the `groupby` function to get, for each day, the counts for all the case categories. Plot the result for the top 5 categories as you see fit. **(20 pts)**

# %%
# Write your code here

# Different way of grouping the list by date
# s = pd.date_range(start='2015-01-01',periods=60)
# s = boston.groupby(pd.TimeGrouper(freq = "1D"))
s = boston.groupby(pd.Grouper(key='OPEN_DT',freq='1D'))

# For sorting the list
import operator

# A type dictionary of collection, with the sub-dictionary represents the date and all the cases frequency with the date
dic_cases_by_day = {}

for date,date_data in s:
    cases = {}
    for idx, row in date_data.iterrows():
        title = row.CASE_TITLE
        if title in cases:
            cases[title] += 1
        if not (title in cases):
            cases[title] = 1
    dic_cases_by_day[date] = cases
    
    # sort for the top 5 categories
    top_5 = dict(sorted(cases.iteritems(), key=operator.itemgetter(1), reverse=True)[:5])
    print date
    # Choose to print the counts for all the case categories for each day
    # pprint(cases)
    pprint(top_5)
# Out:
# 2015-01-01 00:00:00
# {'Heat - Excessive  Insufficient': 11,
#  'Request for Pothole Repair': 12,
#  'Requests for Street Cleaning': 16,
#  'Schedule Bulk Item Pickup': 9,
#  'Sticker Request': 6}
# 2015-01-02 00:00:00
# {'Front Desk Interactions': 11,
#  'Request for Pothole Repair': 20,
#  'Requests for Street Cleaning': 133,
#  'Schedule Bulk Item Pickup': 11,
#  'Schedule a Bulk Item Pickup': 54}
# 2015-01-03 00:00:00
# {'Abandoned Vehicles': 8,
#  'Request for Snow Plowing': 30,
#  'Requests for Street Cleaning': 26,
#  'Schedule Bulk Item Pickup': 15,
#  'outage////printed': 20}
# 2015-01-04 00:00:00
# {'Request for Snow Plowing': 8,
#  'Requests for Street Cleaning': 11,
#  'Schedule Bulk Item Pickup': 13,
#  'Traffic Signal Repair': 10,
#  'outage////printed': 7}
# 2015-01-05 00:00:00
# {'Message Taken': 15,
#  'Request for Pothole Repair': 59,
#  'Requests for Street Cleaning': 62,
#  'Schedule Bulk Item Pickup': 25,
#  'Schedule a Bulk Item Pickup': 73}
# 2015-01-06 00:00:00
# {'Heat - Excessive  Insufficient': 19,
#  'Request for Pothole Repair': 30,
#  'Requests for Street Cleaning': 52,
#  'Schedule Bulk Item Pickup': 21,
#  'Schedule a Bulk Item Pickup': 41}
# 2015-01-07 00:00:00
# {'Heat - Excessive  Insufficient': 17,
#  'Requests for Street Cleaning': 20,
#  'Schedule Bulk Item Pickup': 20,
#  'Schedule a Bulk Item Pickup': 35,
#  'Unsatisfactory Living Conditions': 14}
# 2015-01-08 00:00:00
# {'Heat - Excessive  Insufficient': 62,
#  'Request for Pothole Repair': 26,
#  'Requests for Street Cleaning': 41,
#  'Schedule a Bulk Item Pickup': 36,
#  'Tree Maintenance Requests': 58}
# 2015-01-09 00:00:00
# {'Heat - Excessive  Insufficient': 26,
#  'PRINTED': 16,
#  'Schedule a Bulk Item Pickup': 26,
#  'Traffic Signal Repair': 24,
#  'Tree Maintenance Requests': 67}
# 2015-01-10 00:00:00
# {'Request for Pothole Repair': 7,
#  'Request for Snow Plowing': 7,
#  'Requests for Street Cleaning': 9,
#  'Schedule Bulk Item Pickup': 7,
#  'Traffic Signal Repair': 9}
# 2015-01-11 00:00:00
# {'Empty Litter Basket': 9,
#  'Heat - Excessive  Insufficient': 9,
#  'Pick up Dead Animal': 7,
#  'Requests for Street Cleaning': 15,
#  'Schedule Bulk Item Pickup': 9}
# 2015-01-12 00:00:00
# {'Message Taken': 13,
#  'Request for Pothole Repair': 24,
#  'Requests for Street Cleaning': 45,
#  'Schedule a Bulk Item Pickup': 55,
#  'Tree Maintenance Requests': 63}
# 2015-01-13 00:00:00
# {'Message Taken': 16,
#  'PRINTED': 59,
#  'Request for Pothole Repair': 23,
#  'Requests for Street Cleaning': 20,
#  'Schedule a Bulk Item Pickup': 40}
# 2015-01-14 00:00:00
# {'PRINTED': 18,
#  'Pothole Repair (Internal)': 26,
#  'Request for Pothole Repair': 42,
#  'Requests for Street Cleaning': 66,
#  'Schedule a Bulk Item Pickup': 32}
# 2015-01-15 00:00:00
# {'Request for Pothole Repair': 42,
#  'Request for Snow Plowing': 31,
#  'Requests for Street Cleaning': 30,
#  'Schedule a Bulk Item Pickup': 32,
#  'Street Light Outages': 27}
# 2015-01-16 00:00:00
# {'Front Desk Interactions': 14,
#  'Pothole Repair (Internal)': 110,
#  'Requests for Street Cleaning': 40,
#  'Schedule a Bulk Item Pickup': 15,
#  'Snow Removal': 17}
# 2015-01-17 00:00:00
# {'Animal Generic Request': 7,
#  'Heat - Excessive  Insufficient': 13,
#  'Request for Snow Plowing': 7,
#  'Requests for Street Cleaning': 17,
#  'Schedule Bulk Item Pickup': 8}
# 2015-01-18 00:00:00
# {'Empty Litter Basket': 9,
#  'Request for Pothole Repair': 13,
#  'Requests for Street Cleaning': 30,
#  'Schedule Bulk Item Pickup': 10,
#  'Sticker Request': 5}
# 2015-01-19 00:00:00
# {'Request for Pothole Repair': 10,
#  'Request for Snow Plowing': 19,
#  'Requests for Street Cleaning': 23,
#  'Schedule Bulk Item Pickup': 24,
#  'Schedule a Bulk Item Pickup': 11}
# 2015-01-20 00:00:00
# {'Front Desk Interactions': 25,
#  'PWD Graffiti': 383,
#  'Request for Pothole Repair': 47,
#  'Requests for Street Cleaning': 66,
#  'Schedule a Bulk Item Pickup': 54}
# 2015-01-21 00:00:00
# {'Front Desk Interactions': 25,
#  'News Boxes': 28,
#  'Request for Pothole Repair': 37,
#  'Requests for Street Cleaning': 46,
#  'Schedule a Bulk Item Pickup': 38}
# 2015-01-22 00:00:00
# {'Graffiti Removal': 13,
#  'Request for Pothole Repair': 36,
#  'Requests for Street Cleaning': 53,
#  'Schedule a Bulk Item Pickup': 34,
#  'Sign Repair': 20}
# 2015-01-23 00:00:00
# {'PRINTED': 15,
#  'Pothole Repair (Internal)': 55,
#  'Request for Pothole Repair': 31,
#  'Requests for Street Cleaning': 32,
#  'Schedule a Bulk Item Pickup': 36}
# 2015-01-24 00:00:00
# {'PublicWorks: Complaint': 10,
#  'Request for Snow Plowing': 177,
#  'Requests for Street Cleaning': 11,
#  'Snow Removal': 28,
#  'Traffic Signal Repair': 15}
# 2015-01-25 00:00:00
# {'PRINTED': 12,
#  'Request for Snow Plowing': 67,
#  'Snow Removal': 146,
#  'Space Savers': 9,
#  'Traffic Signal Repair': 10}
# 2015-01-26 00:00:00
# {'Heat - Excessive  Insufficient': 24,
#  'Request for Snow Plowing': 69,
#  'Schedule a Bulk Item Pickup': 11,
#  'Snow Removal': 176,
#  'Space Savers': 32}
# 2015-01-27 00:00:00
# {'Misc. Snow Complaint': 35,
#  'Request for Snow Plowing': 1459,
#  'Request for Snow Plowing (Emergency Responder)': 59,
#  'Snow Removal': 78,
#  'Youthline Idea Collection': 32}
# 2015-01-28 00:00:00
# {'City/State Snow Issues': 27,
#  'Misc. Snow Complaint': 86,
#  'Request for Snow Plowing': 2474,
#  'Request for Snow Plowing (Emergency Responder)': 46,
#  'Snow Removal': 407}
# 2015-01-29 00:00:00
# {'MBTA': 36,
#  'Misc. Snow Complaint': 40,
#  'Request for Snow Plowing': 1646,
#  'Request for Snow Plowing (Emergency Responder)': 42,
#  'Snow Removal': 651}
# 2015-01-30 00:00:00
# {'Misc. Snow Complaint': 24,
#  'Missed Trash: District 1C': 28,
#  'Request for Snow Plowing': 658,
#  'Request for Snow Plowing (Emergency Responder)': 32,
#  'Snow Removal': 575}
# 2015-01-31 00:00:00
# {'Empty Litter Basket': 20,
#  'Heat - Excessive  Insufficient': 13,
#  'Request for Snow Plowing': 245,
#  'Snow Removal': 162,
#  'Traffic Signal Repair': 13}
# 2015-02-01 00:00:00
# {'Empty Litter Basket': 24,
#  'Request for Snow Plowing': 148,
#  'Requests for Street Cleaning': 18,
#  'Snow Removal': 114,
#  'Traffic Signal Repair': 8}
# 2015-02-02 00:00:00
# {'Other: Complaint': 52,
#  'Parking Enforcement': 50,
#  'PublicWorks: Complaint': 39,
#  'Request for Snow Plowing': 1163,
#  'Snow Removal': 135}
# 2015-02-03 00:00:00
# {'Misc. Snow Complaint': 76,
#  'Missed Trash: District 02': 39,
#  'Request for Snow Plowing': 1826,
#  'Request for Snow Plowing (Emergency Responder)': 41,
#  'Snow Removal': 667}
# 2015-02-04 00:00:00
# {'Misc. Snow Complaint': 82,
#  'Missed Trash: District 07': 82,
#  'Other: Complaint': 86,
#  'Request for Snow Plowing': 1346,
#  'Snow Removal': 894}
# 2015-02-05 00:00:00
# {'Empty Litter Basket': 42,
#  'Misc. Snow Complaint': 47,
#  'Request for Pothole Repair': 32,
#  'Request for Snow Plowing': 808,
#  'Snow Removal': 544}
# 2015-02-06 00:00:00
# {'Empty Litter Basket': 46,
#  'Misc. Snow Complaint': 36,
#  'Request for Pothole Repair': 34,
#  'Request for Snow Plowing': 563,
#  'Snow Removal': 348}
# 2015-02-07 00:00:00
# {'Empty Litter Basket': 29,
#  'Missed Trash: District 03': 14,
#  'Missed Trash: District 1C': 25,
#  'Request for Snow Plowing': 252,
#  'Snow Removal': 234}
# 2015-02-08 00:00:00
# {'Empty Litter Basket': 12,
#  'Misc. Snow Complaint': 11,
#  'PublicWorks: Complaint': 16,
#  'Request for Snow Plowing': 338,
#  'Snow Removal': 117}
# 2015-02-09 00:00:00
# {'Misc. Snow Complaint': 37,
#  'Parking Enforcement': 39,
#  'PublicWorks: Complaint': 32,
#  'Request for Snow Plowing': 992,
#  'Snow Removal': 136}
# 2015-02-10 00:00:00
# {'Fire Department': 33,
#  'Misc. Snow Complaint': 84,
#  'Parking Enforcement': 36,
#  'Request for Snow Plowing': 1182,
#  'Snow Removal': 445}
# 2015-02-11 00:00:00
# {'Misc. Snow Complaint': 57,
#  'Missed Trash: District 03': 39,
#  'Request for Pothole Repair': 46,
#  'Request for Snow Plowing': 1072,
#  'Snow Removal': 585}
# 2015-02-12 00:00:00
# {'Misc. Snow Complaint': 47,
#  'Missed Trash: District 03': 38,
#  'Missed Trash: District 07': 31,
#  'Request for Snow Plowing': 960,
#  'Snow Removal': 503}
# 2015-02-13 00:00:00
# {'Missed Trash: District 10A': 28,
#  'Missed Trash: District 1C': 35,
#  'Request for Pothole Repair': 28,
#  'Request for Snow Plowing': 710,
#  'Snow Removal': 328}
# 2015-02-14 00:00:00
# {'Missed Trash: District 02': 22,
#  'Missed Trash: District 07': 20,
#  'Missed Trash: District 1C': 30,
#  'Request for Snow Plowing': 285,
#  'Snow Removal': 114}
# 2015-02-15 00:00:00
# {'Misc. Snow Complaint': 1}

# %%
# plot
# Plots the high-occuring categories for cases as a horizontal histogram.
top_all_5 = dict(sorted(titles_250.iteritems(), key=operator.itemgetter(1), reverse=True)[:5])
num_appear = [top_all_5[i] for i in top_all_5]
title_label = [i for i in top_all_5]
# print num_appear, title_label
y_pos = [i for i in range(len(num_appear))]
plt.barh(y_pos,num_appear,align='center')
plt.yticks(y_pos, title_label)
# Out:
# ([<matplotlib.axis.YTick at 0x10cdf4fd0>,
#   <matplotlib.axis.YTick at 0x10cdf9c90>,
#   <matplotlib.axis.YTick at 0x113377750>,
#   <matplotlib.axis.YTick at 0x116e7f950>,
#   <matplotlib.axis.YTick at 0x10cd37110>],
#  <a list of 5 Text yticklabel objects>)

# %% [markdown]
# Let's see how this trend compares to the snowfall. First, we need to read the data from `snow.csv`

# %%
# Read the dataframe
snow_data = pd.read_csv("snow.csv",parse_dates=[1])

# %% [markdown]
# According to the documentation, the column `SNOW` has the values for the snowfall, in mm. However, the dataset we have has information from many different stations around Boston. Aggregate all their measurements and transform the result to centimeters. Finally, plot the result **(10 pts)**

# %%
# Write your code here
snow_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1416 entries, 0 to 1415
# Data columns (total 4 columns):
# STATION    1416 non-null object
# DATE       1416 non-null datetime64[ns]
# SNWD       1416 non-null int64
# SNOW       1416 non-null int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 55.3+ KB

# %%
# DATA cleaning. EX: get rid of the -9999 by adding a new clean column

for idx, row in snow_data.iterrows():
    if row.SNOW < 0:
        snow_data.ix[idx,'SNOW_NET']=0
    else:
        snow_data.ix[idx,'SNOW_NET']=snow_data.ix[idx,'SNOW']

# %%
# Group the data by date and calculate the mean of snow per day from different stations
snow_by_day = snow_data.groupby(pd.Grouper(key='DATE',freq='1D'))
snow_mean = snow_by_day.SNOW_NET.mean()

# %%
snow_mean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45 entries, 2015-01-01 00:00:00 to 2015-02-14 00:00:00
# Freq: D
# Data columns (total 1 columns):
# SNOW_NET    45 non-null float64
# dtypes: float64(1)
# memory usage: 720.0 bytes

# %%
# Plot the result
snow_mean.plot(label='snow')
plt.legend()

# %% [markdown]
# ## Step 4. Matching trends

# %% [markdown]
# The last thing we will do is to join the snowfall dataframe with that of the top 5 categories of calls, per day. Don't forget to fill the NaN values with 0. You want to do an outer join (if there are calls for a day but no snowfall data, we want to create a 0 record). Save that to a dataframe called `calls_on_snow`. The first 5 columns should be the counts for the categories, and the 6th will be the snowfall data. **(10 pts)**

# %%
calls_on_snow = pd.DataFrame(snow_mean, columns=['Request for Snow Plowing','Snow Removal','Requests for Street Cleaning','Request for Pothole Repair','Misc. Snow Complaint','SNOW'])

for idx, row in calls_on_snow.iterrows():
    day = dic_cases_by_day[idx]
    if 'Request for Snow Plowing' in day:
        row['Request for Snow Plowing'] = day['Request for Snow Plowing']
    else:
        row['Request for Snow Plowing'] = 0
    if 'Snow Removal' in day:
        row['Snow Removal'] = day['Snow Removal']
    else:
        row['Snow Removal'] = 0
    if 'Requests for Street Cleaning' in day:
        row['Requests for Street Cleaning'] = day['Requests for Street Cleaning']
    else:
        row['Requests for Street Cleaning'] = 0
    if 'Request for Pothole Repair' in day:
        row['Request for Pothole Repair'] = day['Request for Pothole Repair']
    else:
        row['Request for Pothole Repair'] = 0
    if 'Misc. Snow Complaint' in day:
        row['Misc. Snow Complaint'] = day['Misc. Snow Complaint']
    else:
        row['Misc. Snow Complaint'] = 0

calls_on_snow.SNOW = snow_mean.SNOW_NET

calls_on_snow
# Out:
#             Request for Snow Plowing  Snow Removal  \
# DATE
# 2015-01-01                         0             0
# 2015-01-02                         2             0
# 2015-01-03                        30             1
# 2015-01-04                         8             0
# 2015-01-05                         2             0
# 2015-01-06                        10             0
# 2015-01-07                         8             1
# 2015-01-08                         4             1
# 2015-01-09                         6             2
# 2015-01-10                         7             7
# 2015-01-11                         4             0
# 2015-01-12                         3             2
# 2015-01-13                        11             2
# 2015-01-14                         7             0
# 2015-01-15                        31             6
# 2015-01-16                        14            17
# 2015-01-17                         7             7
# 2015-01-18                         0             0
# 2015-01-19                        19             0
# 2015-01-20                         2             0
# 2015-01-21                         2             0
# 2015-01-22                         1             1
# 2015-01-23                         1             0
# 2015-01-24                       177            28
# 2015-01-25                        67           146
# 2015-01-26                        69           176
# 2015-01-27                      1459            78
# 2015-01-28                      2474           407
# 2015-01-29                      1646           651
# 2015-01-30                       658           575
# 2015-01-31                       245           162
# 2015-02-01                       148           114
# 2015-02-02                      1163           135
# 2015-02-03                      1826           667
# 2015-02-04                      1346           894
# 2015-02-05                       808           544
# 2015-02-06                       563           348
# 2015-02-07                       252           234
# 2015-02-08                       338           117
# 2015-02-09                       992           136
# 2015-02-10                      1182           445
# 2015-02-11                      1072           585
# 2015-02-12                       960           503
# 2015-02-13                       710           328
# 2015-02-14                       285           114
#
#             Requests for Street Cleaning  Request for Pothole Repair  \
# DATE
# 2015-01-01                            16                          12
# 2015-01-02                           133                          20
# 2015-01-03                            26                           1
# 2015-01-04                            11                           4
# 2015-01-05                            62                          59
# 2015-01-06                            52                          30
# 2015-01-07                            20                          12
# 2015-01-08                            41                          26
# 2015-01-09                            11                          12
# 2015-01-10                             9                           7
# 2015-01-11                            15                           1
# 2015-01-12                            45                          24
# 2015-01-13                            20                          23
# 2015-01-14                            66                          42
# 2015-01-15                            30                          42
# 2015-01-16                            40                          14
# 2015-01-17                            17                           2
# 2015-01-18                            30                          13
# 2015-01-19                            23                          10
# 2015-01-20                            66                          47
# 2015-01-21                            46                          37
# 2015-01-22                            53                          36
# 2015-01-23                            32                          31
# 2015-01-24                            11                           2
# 2015-01-25                             5                           4
# 2015-01-26                            10                           5
# 2015-01-27                             0                           0
# 2015-01-28                             4                           1
# 2015-01-29                             3                           8
# 2015-01-30                            16                          18
# 2015-01-31                            12                          10
# 2015-02-01                            18                           7
# 2015-02-02                             5                           6
# 2015-02-03                            17                           9
# 2015-02-04                            19                          19
# 2015-02-05                            18                          32
# 2015-02-06                            14                          34
# 2015-02-07                            12                          12
# 2015-02-08                             2                           6
# 2015-02-09                             2                           2
# 2015-02-10                            11                          16
# 2015-02-11                             8                          46
# 2015-02-12                             9                          27
# 2015-02-13                            13                          28
# 2015-02-14                            10                          13
#
#             Misc. Snow Complaint        SNOW
# DATE
# 2015-01-01                     0    0.000000
# 2015-01-02                     0    0.000000
# 2015-01-03                     0    5.862069
# 2015-01-04                     0   27.823529
# 2015-01-05                     0    0.000000
# 2015-01-06                     0    0.968750
# 2015-01-07                     2    3.055556
# 2015-01-08                     0    0.470588
# 2015-01-09                     0    1.461538
# 2015-01-10                     0   14.242424
# 2015-01-11                     0    0.000000
# 2015-01-12                     0    0.500000
# 2015-01-13                     0    0.000000
# 2015-01-14                     0    0.000000
# 2015-01-15                     0    5.303030
# 2015-01-16                     0    4.277778
# 2015-01-17                     0    0.000000
# 2015-01-18                     0    0.000000
# 2015-01-19                     0    0.000000
# 2015-01-20                     0    0.000000
# 2015-01-21                     0    0.000000
# 2015-01-22                     0    0.103448
# 2015-01-23                     0    0.000000
# 2015-01-24                     3   67.388889
# 2015-01-25                     2   69.514286
# 2015-01-26                     7    6.812500
# 2015-01-27                    35  373.484848
# 2015-01-28                    86  250.111111
# 2015-01-29                    40    0.000000
# 2015-01-30                    24    4.540541
# 2015-01-31                     5   25.270270
# 2015-02-01                     0    0.088235
# 2015-02-02                    38  130.588235
# 2015-02-03                    76  207.388889
# 2015-02-04                    82    0.000000
# 2015-02-05                    47   15.242424
# 2015-02-06                    36   29.333333
# 2015-02-07                     7    1.457143
# 2015-02-08                    11   86.870968
# 2015-02-09                    37  179.125000
# 2015-02-10                    84  190.000000
# 2015-02-11                    57    1.781250
# 2015-02-12                    47    7.218750
# 2015-02-13                    24   17.962963
# 2015-02-14                    17    0.166667

# %% [markdown]
# Now, you can show the connection of the two trends (the calls and the snow) in a plot. I provide some sample code, but you should also try your own versions.

# %%
fig, axes = plt.subplots(nrows=2,figsize=(12,5), sharex=True)

calls_on_snow.ix[:,0:5].plot(ax=axes[0])
calls_on_snow.ix[:,5].plot(ax=axes[1],label="snowfall (in cm)", color='gray')

axes[0].set_title("The effect of the winter snowstorms on Boston's 311 Hotline for 2015")
axes[0].set_ylabel("# Calls")
axes[1].set_ylabel("Snowfall in cm")
axes[1].set_xlabel("Date")
axes[0].xaxis.grid(False)
axes[1].xaxis.grid(False)

# %% [markdown]
# The result should look something like this:
#
#
# ![The calls to 311 are peaking after each snowstorm](final_plot.png)

# %%
# Code for setting the style of the notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("../../theme/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=EB+Garamond' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     .code_cell {
#         width: 105ex !important ;
#         margin-bottom: 15px !important;
#     }
#     div.cell {
#         margin-left: auto;
#         margin-right: auto;
#         width: 70%;
#     }
#     div.cell.selected {
#         border: thin rgba(171, 171, 171, 0.5) dashed;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'EB Garamond', serif;
#     }
#     h3 {
#         font-family: 'EB Garamond', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#     }
#     h4 {
#         font-family: 'EB Garamond', serif;
#     }
#     h5 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     div.text_cell_render {
#         font-family: 'EB Garamond',Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 140%;
#     }
#     div.input_area {
#         border-color: rgba(0,0,0,0.10) !important;
#         background: #fafafa;
#     }
#     .CodeMirror {
#             font-family: "Source Code Pro";
#             font-size: 90%;
#     }
#     .prompt {
#         display: None;
#     }
#     .output {
#         padding-left: 50px;
#         padding-top: 5px;
#     }
#     .output_wrapper {
#         padding-left: 5px;
#         padding-top: inherit;
#     }
#     div.output_scroll {
#         width: inherit;
#     }
#     .inner_cell {
#         padding-left: 5px;
#     }
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 50pt;
#         line-height: 100%;
#         color:#CD2305;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #CD2305;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .warning {
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
